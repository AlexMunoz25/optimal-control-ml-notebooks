# %% [markdown]
# ### 1.1.2.6. Norm of a Vector (Euclidean)

# %% [markdown]
# $$
# \|\mathbf{v}\| = \sqrt{\sum_{i=1}^{n} v_i^2} = \sqrt{v_1^2 + v_2^2 + \cdots + v_n^2}
# $$

# %% [markdown]
# **Explanation:**
#
# The Euclidean norm measures the magnitude (length) of a vector.
# It is useful in optimization and distance computations in ML.
#
# **Related concepts:**
# - Builds on [Vectors](./01_vector_definition.ipynb).
# - This magnitude concept is used in [Dot Product](./04_vector_dot_product.ipynb) and later extended to [Matrix Frobenius Norm](../03_Matrix/15_matrix_frobenius_norm.ipynb).
#
# **Example:**
#
# If
#
# $$
# \mathbf{v} =
# \begin{bmatrix}
# 3 \\
# 4
# \end{bmatrix},
# $$
#
# then
#
# $$
# \|\mathbf{v}\| = \sqrt{3^2 + 4^2} = 5.
# $$

# %%
import sympy as sp

vector_v = sp.Matrix([3, 4])

euclidean_norm = vector_v.norm()

print("‖v‖ =", euclidean_norm)
# Out:
# ‖v‖ = 5.0

# %% [markdown]
# **References:**
#
# [📘 Aazi, M. (2024). *Mathematics For Machine Learning*](https://www.scribd.com/document/812294393/Mathematics-for-Machine-Learning)
#
# [📗 Fleisch, D. (2012). *A Student's Guide to Vectors and Tensors.* Cambridge University Press.](https://www.cambridge.org/core/books/students-guide-to-vectors-and-tensors/46EB80DBBF3C1C1B06F1B9E34C6D7753)
#
# ---
#
# [⬅️ Previous: Cross Product](./05_vector_cross_product_3d.ipynb) | [Next: Orthogonality Condition ➡️](./07_vector_orthogonality_condition.ipynb)
