# %% [markdown]
# ### 3.2.5.2. Dual Problem and Weak Duality

# %% [markdown]
# $$\max_{\lambda,\nu}g(\lambda,\nu)\quad\text{subject to}\quad\lambda\succeq0$$

# %% [markdown]
# **Explanation:**
#
# The dual problem maximizes the Lagrange dual function over dual-feasible multipliers. Weak duality guarantees that every dual-feasible value is a lower bound on the primal optimum, so any primal-dual pair gives a computable gap.
#
# **Properties:**
# - Weak duality gives a lower bound for minimization.
# - A primal feasible point gives an upper bound.
# - A zero gap proves optimality when both sides are feasible.
#
# **Intuition:**
#
# The example treats the numbers as certificates rather than as iterates.

# %% [markdown]
# **Numerical Example:**
#
# Suppose a primal feasible point has value $p=4$ and a dual feasible point has value $d=3$. Weak duality gives
# $$
# d\leq p^\star\leq p.
# $$
#
# Substitute the values:
# $$
# 3\leq p^\star\leq4.
# $$
#
# The certificate gap is
# $$
# p-d=4-3=1.
# $$
#
# The dual point proves that no feasible primal solution can have value below $3$, while the primal point proves the optimum is at most $4$.

# %%
import sympy as sp

primal_value = sp.Integer(4)
bound_value = sp.Integer(3)
gap = primal_value - bound_value

bound_value <= primal_value, gap
# Out:
# (True, 1)

# %% [markdown]
# **References:**
#
# [📘 Boyd, S., & Vandenberghe, L. (2004). *Convex Optimization*. Cambridge University Press.](https://web.stanford.edu/~boyd/cvxbook/)
#
# ---
#
# [⬅️ Previous: Lagrangian and Dual Function](./01_lagrangian_and_dual_function.ipynb) | [Next: Strong Duality and Slater Condition ➡️](./03_strong_duality_and_slaters_condition.ipynb)
#
# ---
