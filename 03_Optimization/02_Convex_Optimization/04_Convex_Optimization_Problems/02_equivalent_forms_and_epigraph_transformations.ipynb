# %% [markdown]
# ### 3.2.4.2. Equivalent Forms and Epigraph Transformations

# %% [markdown]
# $$\min_x f_0(x)\Longleftrightarrow\min_{x,t}t\quad\text{subject to}\quad f_0(x)\leq t$$

# %% [markdown]
# **Explanation:**
#
# Epigraph transformations introduce an auxiliary variable that stands above an objective or constraint function. Minimizing the original function can then be written as minimizing this height variable subject to an epigraph constraint.
#
# The left problem minimizes $f_0(x)$ directly. The right problem introduces a scalar $t$ and minimizes that height subject to $f_0(x)\leq t$, which is the [epigraph](../03_Convex_Functions/05_sublevel_sets_and_epigraphs.ipynb) form of the same objective.
#
# **Properties:**
# - [Convex functions](../03_Convex_Functions/01_convex_function_definition_and_examples.ipynb) have convex [epigraphs](../03_Convex_Functions/05_sublevel_sets_and_epigraphs.ipynb).
# - Quasiconvex functions have convex sublevel sets.
# - Epigraph transformations replace objectives by constraints.
#
# **Intuition:**
#
# The figure above shows set membership derived from a function value; the arithmetic checks that membership.
#
# <img src="../../../Figures/03020402_bv_fig_4_1_epigraph_form.jpeg" alt="Boyd and Vandenberghe Figure 4.1: geometric interpretation of epigraph form" style="width: 60%; height: auto;">

# %% [markdown]
# **Numerical Example:**
#
# The figure above shows set membership derived from a function value; the arithmetic checks that membership.
#
# Let $f(x)=x^2$ and $x=2$. First compute
# $$
# f(2)=2^2=4.
# $$
#
# At level $5$,
# $$
# 4\leq5,
# $$
# so $x=2$ is in the sublevel set. At level $3$,
# $$
# 4\leq3
# $$
# is false, so $x=2$ is not in that lower sublevel set.

# %%
import sympy as sp

function_value = sp.Integer(2) ** 2

print("function_value <= 5 =", function_value <= 5)
print("function_value <= 3 =", function_value <= 3)
# Out:
# function_value <= 5 = True
# function_value <= 3 = False

# %% [markdown]
# **References:**
#
# [📘 Boyd, S., & Vandenberghe, L. (2004). *Convex Optimization*. Cambridge University Press.](https://web.stanford.edu/~boyd/cvxbook/)
#
# ---
#
# [⬅️ Previous: Standard Form and Problem Transformations](./01_standard_form_and_problem_transformations.ipynb) | [Next: Convex Problem Standard Form and Optimality ➡️](./03_convex_problem_standard_form_and_optimality.ipynb)
#
# ---
