# %% [markdown]
# ### 1.1.7.26. QR Decomposition

# %% [markdown]
# $$
# A = Q R
# $$

# %% [markdown]
# **Explanation:**
#
# The QR decomposition factors a matrix into an orthogonal matrix and an upper-triangular matrix. It is closely tied to [Gram-Schmidt orthogonalization](./16_gram_schmidt_orthogonalization.ipynb), which produces the orthonormal columns of $Q$.
#
# **Example:**
#
# The columns of $Q$ are the orthonormalized columns of $A$, while $R$ stores the coefficients needed to reconstruct the original matrix.

# %%
import sympy as sp

matrix_a = sp.Matrix([[1, 1], [1, 0], [0, 1]])
matrix_q, matrix_r = matrix_a.QRdecomposition()

print("matrix_q =")
sp.pprint(matrix_q)
print("matrix_r =")
sp.pprint(matrix_r)
# Out:
# matrix_q =
# ⎡√2   √6 ⎤
# ⎢──   ── ⎥
# ⎢2    6  ⎥
# ⎢        ⎥
# ⎢√2  -√6 ⎥
# ⎢──  ────⎥
# ⎢2    6  ⎥
# ⎢        ⎥
# ⎢     √6 ⎥
# ⎢0    ── ⎥
# ⎣     3  ⎦
# matrix_r =
# ⎡    √2⎤
# ⎢√2  ──⎥
# ⎢    2 ⎥
# ⎢      ⎥
# ⎢    √6⎥
# ⎢0   ──⎥
# ⎣    2 ⎦

# %% [markdown]
# **References:**
#
# [📘 Savov, I. (2016). *No Bullshit Guide to Linear Algebra*, Section 7.6 "QR decomposition".](https://minireference.com/static/excerpts/noBSLA_v2_preview.pdf)
#
# ---
#
# [⬅️ Previous: LU Decomposition](./25_lu_decomposition.ipynb) | [Next: Cholesky Decomposition ➡️](./27_cholesky_decomposition.ipynb)
#
# ---
