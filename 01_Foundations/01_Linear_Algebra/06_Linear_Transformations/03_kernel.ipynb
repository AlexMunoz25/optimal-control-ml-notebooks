# %% [markdown]
# ### 1.1.6.3. Kernel

# %% [markdown]
# $$
# \operatorname{Ker}(T) =
# \left\{
# \mathbf{v} \in V \mid T(\mathbf{v}) = \mathbf{0}
# \right\}
# $$

# %% [markdown]
# **Explanation:**
#
# The kernel is the set of inputs that a linear transformation sends to the zero vector. Savov interprets it as the transformation analogue of the [null space](../05_Geometrical_Aspects_of_Linear_Algebra/16_matrix_fundamental_spaces.ipynb), so this notebook keeps the focus on lost directions in the input space. The connection between kernel size and invertibility is deferred to [invertible linear transformations](./07_invertible_linear_transformation.ipynb).
#
# **Example:**
#
# For
#
# $$
# T(x, y, z) =
# \begin{bmatrix}
# x \\
# z
# \end{bmatrix},
# $$
#
# the kernel is
#
# $$
# \operatorname{Ker}(T) =
# \operatorname{span}
# \left\{
# \begin{bmatrix}
# 0 \\
# 1 \\
# 0
# \end{bmatrix}
# \right\}.
# $$

# %%
import sympy as sp

transformation_matrix = sp.Matrix([[1, 0, 0], [0, 0, 1]])
kernel_basis = transformation_matrix.nullspace()

print("kernel_basis =", kernel_basis)

# %% [markdown]
# **References:**
#
# [Savov, I. (2016). *No Bullshit Guide to Linear Algebra*, Section 6.1 "Input and output spaces".](https://minireference.com/static/excerpts/noBSLA_v2_preview.pdf)
#
# ---
#
# [Previous: Image Space](./02_image_space.ipynb) | [Next: Injective, Surjective, and Bijective Transformations](./04_injective_surjective_bijective.ipynb)
#
# ---
