# %% [markdown]
# ### 1.1.5.3. Line as the Intersection of Two Planes

# %% [markdown]
# $$
# \begin{aligned}
# A_1 x + B_1 y + C_1 z &= D_1 \\
# A_2 x + B_2 y + C_2 z &= D_2
# \end{aligned}
# $$

# %% [markdown]
# **Explanation:**
#
# Two nonparallel planes intersect in a line. Solving the two plane equations simultaneously leaves one free parameter, which produces the line explicitly. This viewpoint relies on the definition of a [plane](./02_plane_in_r3.ipynb) and connects naturally to [reduced row echelon form](../04_Computational_Linear_Algebra/03_reduced_row_echelon_form.ipynb).
#
# **Example:**
#
# If
#
# $$
# \begin{aligned}
# z &= 0 \\
# y + z &= 0,
# \end{aligned}
# $$
#
# then the reduced system implies
#
# $$
# y = 0,
# \qquad
# z = 0,
# \qquad
# x = t,
# $$
#
# so the intersection line is
#
# $$
# \ell = \left\{
# \begin{bmatrix}
# 0 \\
# 0 \\
# 0
# \end{bmatrix}
# + t
# \begin{bmatrix}
# 1 \\
# 0 \\
# 0
# \end{bmatrix}
# \mid t \in \mathbb{R}
# \right\}.
# $$

# %%
import sympy as sp

coefficient_matrix = sp.Matrix([[0, 0, 1], [0, 1, 1]])
constant_vector = sp.Matrix([0, 0])
augmented_matrix = coefficient_matrix.row_join(constant_vector)
reduced_matrix, pivot_columns = augmented_matrix.rref()

print("reduced_matrix =")
sp.pprint(reduced_matrix)
print("pivot_columns =", pivot_columns)
# Out:
# reduced_matrix =
# ⎡0  1  0  0⎤
# ⎢          ⎥
# ⎣0  0  1  0⎦
# pivot_columns = (1, 2)

# %% [markdown]
# **References:**
#
# [📘 Savov, I. (2016). *No Bullshit Guide to Linear Algebra*, Section 5.1 "Lines and planes".](https://minireference.com/static/excerpts/noBSLA_v2_preview.pdf)
#
# ---
#
# [⬅️ Previous: Plane in R^3](./02_plane_in_r3.ipynb) | [Next: Distance Between Two Points ➡️](./04_distance_between_points.ipynb)
#
# ---
