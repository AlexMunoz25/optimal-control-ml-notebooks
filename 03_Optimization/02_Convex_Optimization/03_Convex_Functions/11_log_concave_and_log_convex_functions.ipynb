# %% [markdown]
# ### 3.2.3.11. Log-Concave and Log-Convex Functions

# %% [markdown]
# $$f\ \text{is log-convex}\quad\Longleftrightarrow\quad\log f\ \text{is convex}$$

# %% [markdown]
# **Explanation:**
#
# Log-concavity and log-convexity use a logarithm to expose multiplicative structure. A positive function is log-concave when its logarithm is concave, and log-convex when its logarithm is convex.
#
# The equivalence says a positive function is log-convex exactly when applying the logarithm gives a [convex function](01_convex_function_definition_and_examples.ipynb). The logarithm changes multiplicative structure into additive structure before convexity is checked.
#
# **Properties:**
# - The input average is compared with the average of function values.
# - Quadratics with nonnegative curvature are canonical convex examples.
# - Jensen inequalities extend the same idea to many points.
#
# **Intuition:**
#
# The computation evaluates both sides of the convexity inequality.

# %% [markdown]
# **Numerical Example:**
#
# Let $f(x)=x^2$, $x=0$, $y=2$, and $\theta=1/4$. The averaged input is
# $$
# \theta x+(1-\theta)y=\frac14\cdot0+\frac34\cdot2=\frac32.
# $$
#
# The left side is
# $$
# f(3/2)=(3/2)^2=9/4.
# $$
#
# The right side is
# $$
# \frac14 f(0)+\frac34 f(2)=\frac14\cdot0+\frac34\cdot4=3.
# $$
#
# Since $9/4\leq3$, the convexity inequality holds.

# %%
import sympy as sp

theta = sp.Rational(1, 4)
point_x = sp.Integer(0)
point_y = sp.Integer(2)
midpoint = theta * point_x + (1 - theta) * point_y
left_side = midpoint ** 2
right_side = theta * point_x ** 2 + (1 - theta) * point_y ** 2

print("left_side =", left_side)
print("right_side =", right_side)
print("left_side <= right_side =", left_side <= right_side)
# Out:
# left_side = 9/4
# right_side = 3
# left_side <= right_side = True

# %% [markdown]
# **Equivalent `casadi` implementation:**

# %%
import casadi as ca

theta = 0.25
point_x = ca.DM(0)
point_y = ca.DM(2)
midpoint = theta * point_x + (1 - theta) * point_y
left_side = midpoint ** 2
right_side = theta * point_x ** 2 + (1 - theta) * point_y ** 2

print("left_side =", left_side)
print("right_side =", right_side)
print("left_side <= right_side =", bool(left_side <= right_side))
# Out:
# left_side = 2.25
# right_side = 3
# left_side <= right_side = True

# %% [markdown]
# **References:**
#
# [📘 Boyd, S., & Vandenberghe, L. (2004). *Convex Optimization*. Cambridge University Press.](https://web.stanford.edu/~boyd/cvxbook/)
#
# ---
#
# [⬅️ Previous: Quasiconvex Functions and Bisection View](./10_quasiconvex_functions_and_bisection_view.ipynb) | [Next: Convexity with Generalized Inequalities ➡️](./12_convexity_with_generalized_inequalities.ipynb)
#
# ---
