# %% [markdown]
# ### 1.1.5.4. Distance Between Two Points

# %% [markdown]
# $$
# d(\mathbf{p}, \mathbf{q}) = \lVert \mathbf{q} - \mathbf{p} \rVert
# $$

# %% [markdown]
# **Explanation:**
#
# The distance between two points is the Euclidean length of the displacement vector that connects them. It is the simplest distance formula in the module and follows directly from the [vector norm](../02_Vector/06_vector_norm.ipynb).
#
# **Example:**
#
# If
#
# $$
# \mathbf{p} =
# \begin{bmatrix}
# 1 \\
# 2 \\
# 3
# \end{bmatrix},
# \qquad
# \mathbf{q} =
# \begin{bmatrix}
# 4 \\
# 6 \\
# 3
# \end{bmatrix},
# $$
#
# then
#
# $$
# d(\mathbf{p}, \mathbf{q}) =
# \left\lVert
# \begin{bmatrix}
# 3 \\
# 4 \\
# 0
# \end{bmatrix}
# \right\rVert
# = 5.
# $$

# %%
import sympy as sp

point_p = sp.Matrix([1, 2, 3])
point_q = sp.Matrix([4, 6, 3])
distance_value = (point_q - point_p).norm()

print("point_p =", list(point_p))
print("point_q =", list(point_q))
print("distance_value =", sp.simplify(distance_value))
# Out:
# point_p = [1, 2, 3]
# point_q = [4, 6, 3]
# distance_value = 5

# %% [markdown]
# **References:**
#
# [📘 Savov, I. (2016). *No Bullshit Guide to Linear Algebra*, Section 5.1 "Distance formulas".](https://minireference.com/static/excerpts/noBSLA_v2_preview.pdf)
#
# ---
#
# [⬅️ Previous: Line as the Intersection of Two Planes](./03_line_as_intersection_of_planes.ipynb) | [Next: Distance from a Line to the Origin ➡️](./05_distance_from_line_to_origin.ipynb)
#
# ---
