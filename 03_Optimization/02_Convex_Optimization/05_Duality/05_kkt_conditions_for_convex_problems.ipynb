# %% [markdown]
# ### 3.2.5.5. KKT Conditions for Convex Problems

# %% [markdown]
# $$\nabla f_0(x^*)+\sum_i\lambda_i^*\nabla f_i(x^*)+\sum_i\nu_i^*\nabla h_i(x^*)=0$$

# %% [markdown]
# **Explanation:**
#
# The KKT conditions combine primal feasibility, dual feasibility, stationarity, and complementary slackness. For convex problems with suitable regularity, satisfying these equations certifies global optimality.
#
# This is the stationarity part of the KKT conditions. The gradient of the objective is balanced by multiplier-weighted gradients of the active inequality and equality constraints, so the total first-order variation is zero.
#
# **Properties:**
# - Stationarity balances objective and constraint gradients.
# - Complementary slackness pairs active constraints with nonzero multipliers.
# - Convexity makes the KKT certificate global.
#
# **Intuition:**
#
# The example verifies the nontrivial KKT residuals for one scalar problem.

# %% [markdown]
# **Numerical Example:**
#
# For $\min x^2$ subject to $1-x\leq0$, test $x^\star=1$ and $\lambda^\star=2$.
#
# Primal feasibility gives
# $$
# 1-x^\star=1-1=0\leq0.
# $$
#
# Dual feasibility gives $\lambda^\star=2\geq0$. Stationarity gives
# $$
# 2x^\star-\lambda^\star=2-2=0.
# $$
#
# Complementary slackness gives
# $$
# \lambda^\star(1-x^\star)=2(1-1)=0.
# $$
#
# All KKT residuals vanish.

# %%
import sympy as sp

optimizer = sp.Integer(1)
multiplier = sp.Integer(2)
stationarity = 2 * optimizer - multiplier
slackness = multiplier * (1 - optimizer)

print("stationarity =", stationarity)
print("slackness =", slackness)
# Out:
# stationarity = 0
# slackness = 0

# %% [markdown]
# **References:**
#
# [📘 Boyd, S., & Vandenberghe, L. (2004). *Convex Optimization*. Cambridge University Press.](https://web.stanford.edu/~boyd/cvxbook/)
#
# ---
#
# [⬅️ Previous: Duality Geometry and Saddle Points](./04_duality_geometry_and_saddle_points.ipynb) | [Next: Complementary Slackness and Certificates ➡️](./06_complementary_slackness_and_certificates.ipynb)
#
# ---
