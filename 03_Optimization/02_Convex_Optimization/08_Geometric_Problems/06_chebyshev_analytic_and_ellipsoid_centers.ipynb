# %% [markdown]
# ### 3.2.8.6. Chebyshev, Analytic, and Ellipsoid Centers

# %% [markdown]
# $$\max_{x_c,r}r$$

# %% [markdown]
# **Explanation:**
#
# Centering problems choose representative interior points of [convex sets](../02_Convex_Sets/01_affine_sets_and_convex_sets.ipynb). The Chebyshev center maximizes the radius of an inscribed ball, while analytic and ellipsoid centers use barrier or volume criteria. Feasibility keeps the centered object inside the set; optimality makes it as large or central as possible.
#
# The variables are the candidate center $x_c$ and radius $r$. Maximizing $r$ means choosing the largest ball, centered at $x_c$, that remains inside the feasible set.
#
# **Properties:**
# - The Chebyshev radius is the [distance](../../../01_Foundations/01_Linear_Algebra/05_Geometrical_Aspects_of_Linear_Algebra/04_distance_between_points.ipynb) to the nearest boundary.
# - For an interval, the center is the midpoint.
# - Higher-dimensional versions use convex inequalities.
#
# **Intuition:**
#
# The figure above shows center geometry; the calculation finds the largest interval ball.
#
# <img src="../../../Figures/03020806_bv_fig_8_5_chebyshev_center.jpeg" alt="Boyd and Vandenberghe Figure 8.5: Chebyshev center of a polyhedron" style="width: 60%; height: auto;">

# %% [markdown]
# **Numerical Example:**
#
# The figure above shows center geometry. For the interval $[0,4]$, choose center
# $$
# c=\frac{0+4}{2}=2.
# $$
#
# The distance to the left boundary is
# $$
# 2-0=2,
# $$
# and the distance to the right boundary is
# $$
# 4-2=2.
# $$
#
# Therefore the largest inscribed interval radius is $r=2$.

# %%
import sympy as sp

left_boundary = sp.Integer(0)
right_boundary = sp.Integer(4)
center = (left_boundary + right_boundary) / 2
radius = min(center - left_boundary, right_boundary - center)

print("center =", center)
print("radius =", radius)
# Out:
# center = 2
# radius = 2

# %% [markdown]
# **References:**
#
# [📘 Boyd, S., & Vandenberghe, L. (2004). *Convex Optimization*. Cambridge University Press.](https://web.stanford.edu/~boyd/cvxbook/)
#
# ---
#
# [⬅️ Previous: Extremal Volume Ellipsoids](./05_extremal_volume_ellipsoids.ipynb) | [Next: Linear and Quadratic Classification ➡️](./07_linear_and_quadratic_classification.ipynb)
#
# ---
