# %% [markdown]
# ### 1.1.7.11. Orthogonal Matrix

# %% [markdown]
# $$
# Q^{\mathsf{T}} Q = I
# $$

# %% [markdown]
# **Explanation:**
#
# An orthogonal matrix preserves lengths and angles, and its inverse is its transpose. Savov places rotations and reflections under this broader concept, so this notebook links to the matrix representations of [rotations](../06_Linear_Transformations/11_rotation_matrix_representation.ipynb) and [reflections](../06_Linear_Transformations/10_reflection_matrix_representation.ipynb) rather than re-explaining them geometrically.
#
# **Example:**
#
# A planar rotation matrix is orthogonal because its columns form an orthonormal basis.

# %%
import sympy as sp

rotation_angle = sp.pi / 3
matrix_q = sp.Matrix(
    [
        [sp.cos(rotation_angle), -sp.sin(rotation_angle)],
        [sp.sin(rotation_angle), sp.cos(rotation_angle)],
    ]
)

print("orthogonality_check =")
sp.pprint(sp.simplify(matrix_q.T * matrix_q))

# %% [markdown]
# **References:**
#
# [Savov, I. (2016). *No Bullshit Guide to Linear Algebra*, Section 7.2 "Orthogonal matrices".](https://minireference.com/static/excerpts/noBSLA_v2_preview.pdf)
#
# ---
#
# [Previous: Positive Definite Matrix](./10_positive_definite_matrix.ipynb) | [Next: Projection Matrix as an Idempotent Matrix](./12_projection_matrix_as_idempotent.ipynb)
#
# ---
