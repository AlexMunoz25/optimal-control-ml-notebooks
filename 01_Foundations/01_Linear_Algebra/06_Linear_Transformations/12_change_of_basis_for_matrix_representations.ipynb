# %% [markdown]
# ### 1.1.6.12. Change of Basis for Matrix Representations

# %% [markdown]
# $$
# \left[ T(\mathbf{v}) \right]_{B_W} =
# {}_{B_W}\!\left[ M_T \right]_{B_V}
# \left[ \mathbf{v} \right]_{B_V}
# $$

# %% [markdown]
# **Explanation:**
#
# A matrix is not the transformation itself but its coefficients relative to chosen input and output bases. This basis dependence is the central idea here, and it links directly to [change of basis for vectors](../05_Geometrical_Aspects_of_Linear_Algebra/12_change_of_basis.ipynb). The special square-matrix case is developed in [similarity transformations](./13_similarity_transformation.ipynb).
#
# **Example:**
#
# Changing the basis used for both the input and output spaces replaces the old coefficient matrix with a new one that predicts the same geometric output using different coordinates.

# %%
import sympy as sp

matrix_in_old_basis = sp.Matrix([[1, 0], [0, -1]])
change_of_basis_matrix = sp.Matrix(
    [
        [1 / sp.sqrt(2), 1 / sp.sqrt(2)],
        [1 / sp.sqrt(2), -1 / sp.sqrt(2)],
    ]
)
matrix_in_new_basis = sp.simplify(change_of_basis_matrix.inv() * matrix_in_old_basis * change_of_basis_matrix)

print("matrix_in_new_basis =")
sp.pprint(matrix_in_new_basis)
# Out:
# matrix_in_new_basis =
# ⎡0  1⎤
# ⎢    ⎥
# ⎣1  0⎦

# %% [markdown]
# **References:**
#
# [Savov, I. (2016). *No Bullshit Guide to Linear Algebra*, Section 6.3 "Change of basis for matrices".](https://minireference.com/static/excerpts/noBSLA_v2_preview.pdf)
#
# ---
#
# [Previous: Rotation Matrix Representation](./11_rotation_matrix_representation.ipynb) | [Next: Similarity Transformation](./13_similarity_transformation.ipynb)
#
# ---
