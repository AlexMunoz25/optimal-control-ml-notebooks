# %% [markdown]
# ### 3.2.10.7. KKT Systems and Block Elimination

# %% [markdown]
# $$\begin{bmatrix}H&A^T\\A&0\end{bmatrix}\begin{bmatrix}u\\v\end{bmatrix}=\begin{bmatrix}r\\s\end{bmatrix}$$

# %% [markdown]
# **Explanation:**
#
# KKT block systems are the computational form of equality-constrained stationarity and feasibility equations. Feasibility is the equality constraint or its linearized version; optimality is stationarity together with that feasibility condition.
#
# The block system collects the Hessian-like matrix $H$, constraint matrix $A$, unknown blocks $u$ and $v$, and right-hand-side blocks $r$ and $s$. Block elimination solves this [matrix equation](../../../01_Foundations/01_Linear_Algebra/04_Computational_Linear_Algebra/06_matrix_equations.ipynb) by reducing it to smaller coupled systems.
#
# **Properties:**
# - Equality constraints introduce unrestricted multipliers.
# - KKT systems couple stationarity and feasibility.
# - Eliminating constraints can reduce the number of variables.
#
# **Intuition:**
#
# The numerical example keeps the equality constraint visible in every algebraic step.

# %% [markdown]
# **Numerical Example:**
#
# Solve
# $$
# \begin{bmatrix}4&1\\1&3\end{bmatrix}
# \begin{bmatrix}u_1\\u_2\end{bmatrix}
# =
# \begin{bmatrix}1\\2\end{bmatrix}.
# $$
#
# The [determinant](../../../01_Foundations/01_Linear_Algebra/03_Matrix/10_matrix_determinant.ipynb) is
# $$
# 4\cdot3-1\cdot1=11.
# $$
#
# Thus
# $$
# u_1=\frac{3\cdot1-1\cdot2}{11}=\frac1{11},
# \qquad
# u_2=\frac{-1\cdot1+4\cdot2}{11}=\frac7{11}.
# $$

# %%
import sympy as sp

coefficient_matrix = sp.Matrix([[4, 1], [1, 3]])
right_side = sp.Matrix([1, 2])
solution = coefficient_matrix.LUsolve(right_side)

print("solution =", solution)
# Out:
# solution = Matrix([[1/11], [7/11]])

# %% [markdown]
# **Equivalent `casadi` implementation:**

# %%
import casadi as ca

coefficient_matrix = ca.DM([[4, 1], [1, 3]])
right_side = ca.DM([1, 2])
solution = ca.solve(coefficient_matrix, right_side)

print("solution =", solution)
# Out:
# solution = [0.0909091, 0.636364]

# %% [markdown]
# **References:**
#
# [📘 Boyd, S., & Vandenberghe, L. (2004). *Convex Optimization*. Cambridge University Press.](https://web.stanford.edu/~boyd/cvxbook/)
#
# ---
#
# [⬅️ Previous: Infeasible-Start Newton Method](./06_infeasible_start_newton_method.ipynb) | [Next: Structured Examples: Network Flow and Optimal Control ➡️](./08_structured_examples_network_flow_and_optimal_control.ipynb)
#
# ---
