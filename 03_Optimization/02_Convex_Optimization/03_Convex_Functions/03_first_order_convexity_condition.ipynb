# %% [markdown]
# ### 3.2.3.3. First-Order Convexity Condition

# %% [markdown]
# $$f(y)\geq f(x)+\nabla f(x)^T(y-x)$$

# %% [markdown]
# **Explanation:**
#
# For differentiable [convex functions](01_convex_function_definition_and_examples.ipynb), every tangent line is a global lower bound. The first-order inequality turns gradient information at one point into a certificate that applies across the whole domain.
#
# The point $x$ is where the tangent approximation is built, and $y$ is any comparison point. The term $\nabla f(x)^T(y-x)$ is an [inner product](../../../01_Foundations/01_Linear_Algebra/07_Theoretical_Linear_Algebra/02_inner_product_space.ipynb) between the gradient and the displacement from $x$ to $y$.
#
# **Properties:**
# - The gradient defines the tangent approximation.
# - Convexity keeps the true function above that approximation.
# - At an optimum, the first-order inequality holds against every feasible point.
#
# **Intuition:**
#
# The figure above shows a tangent lower bound; the arithmetic computes the lower bound and the true value.
#
# <img src="../../../Figures/03020303_bv_fig_3_2_first_order_condition.jpeg" alt="Boyd and Vandenberghe Figure 3.2: first-order lower bound for a convex function" style="width: 60%; height: auto;">

# %% [markdown]
# **Numerical Example:**
#
# The figure above shows a tangent lower bound; the arithmetic computes the lower bound and the true value.
#
# Let $f(x)=x^2$, expand around $x=1$, and compare with $y=3$. Since $f'(x)=2x$,
# $$
# f'(1)=2.
# $$
#
# The tangent lower bound at $y=3$ is
# $$
# f(1)+f'(1)(3-1)=1^2+2\cdot2=5.
# $$
#
# The true value is
# $$
# f(3)=3^2=9.
# $$
#
# Because $9\geq5$, the tangent line gives a valid global lower bound.

# %%
import sympy as sp

point_x = sp.Integer(1)
point_y = sp.Integer(3)
lower_bound = point_x ** 2 + 2 * point_x * (point_y - point_x)
true_value = point_y ** 2

print("lower_bound =", lower_bound)
print("true_value =", true_value)
# Out:
# lower_bound = 5
# true_value = 9

# %% [markdown]
# **Equivalent `casadi` implementation:**

# %%
import casadi as ca

variable = ca.SX.sym("x")
objective = variable ** 2
gradient = ca.gradient(objective, variable)
point_x = 1
point_y = 3
function_at_x = ca.evalf(ca.substitute(objective, variable, point_x))
gradient_at_x = ca.evalf(ca.substitute(gradient, variable, point_x))
lower_bound = function_at_x + gradient_at_x * (point_y - point_x)
true_value = ca.evalf(ca.substitute(objective, variable, point_y))

print("lower_bound =", lower_bound)
print("true_value =", true_value)
# Out:
# lower_bound = 5
# true_value = 9

# %% [markdown]
# **References:**
#
# [📘 Boyd, S., & Vandenberghe, L. (2004). *Convex Optimization*. Cambridge University Press.](https://web.stanford.edu/~boyd/cvxbook/)
#
# ---
#
# [⬅️ Previous: Extended-Value Extensions and Domains](./02_extended_value_extensions_and_domains.ipynb) | [Next: Second-Order Convexity Condition ➡️](./04_second_order_convexity_condition.ipynb)
#
# ---
