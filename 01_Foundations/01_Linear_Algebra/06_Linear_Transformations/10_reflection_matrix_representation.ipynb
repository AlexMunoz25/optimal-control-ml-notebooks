# %% [markdown]
# ### 1.1.6.10. Reflection Matrix Representation

# %% [markdown]
# $$
# R_{\ell}(\mathbf{v}) = 2 \Pi_{\ell}(\mathbf{v}) - \mathbf{v}
# $$

# %% [markdown]
# **Explanation:**
#
# A reflection can be built from a projection by doubling the invariant component and subtracting the original vector once. Its geometric meaning depends on [projection onto a line](../05_Geometrical_Aspects_of_Linear_Algebra/07_projection_onto_a_line.ipynb), and the same construction becomes a matrix by acting on basis vectors. Unlike a rotation, a reflection fixes an entire line instead of only the origin.
#
# **Example:**
#
# Reflection across the $x$-axis uses
#
# $$
# M_{R_x} =
# \begin{bmatrix}
# 1 & 0 \\
# 0 & -1
# \end{bmatrix}.
# $$

# %%
import sympy as sp

reflection_matrix = sp.Matrix([[1, 0], [0, -1]])
input_vector = sp.Matrix([2, 3])
output_vector = reflection_matrix * input_vector

print("output_vector =", output_vector)

# %% [markdown]
# **References:**
#
# [Savov, I. (2016). *No Bullshit Guide to Linear Algebra*, Section 6.2 "Reflections".](https://minireference.com/static/excerpts/noBSLA_v2_preview.pdf)
#
# ---
#
# [Previous: Projection Matrix Representation](./09_projection_matrix_representation.ipynb) | [Next: Rotation Matrix Representation](./11_rotation_matrix_representation.ipynb)
#
# ---
