# %% [markdown]
# ### 1.1.7.2. Eigenvector

# %% [markdown]
# $$
# (A - \lambda I) \mathbf{e}_{\lambda} = \mathbf{0}
# $$

# %% [markdown]
# **Explanation:**
#
# An eigenvector is a nonzero vector whose direction is unchanged by the matrix action. Savov defines eigenvectors as the nonzero solutions of the null-space problem associated with an [eigenvalue](./01_eigenvalue.ipynb), so this notebook keeps the dependence explicit rather than collapsing both ideas into one notebook. The collection of all eigenvectors for one eigenvalue is handled separately in [eigenspaces](./03_eigenspace.ipynb).
#
# **Example:**
#
# For the eigenvalue $5$ of
#
# $$
# A =
# \begin{bmatrix}
# 9 & -2 \\
# -2 & 6
# \end{bmatrix},
# $$
#
# one eigenvector is
#
# $$
# \mathbf{e}_5 =
# \begin{bmatrix}
# 1 \\
# 2
# \end{bmatrix}.
# $$

# %%
import sympy as sp

matrix_a = sp.Matrix([[9, -2], [-2, 6]])
eigenvector_data = matrix_a.eigenvects()

print("eigenvector_data =", eigenvector_data)

# %% [markdown]
# **References:**
#
# [Savov, I. (2016). *No Bullshit Guide to Linear Algebra*, Section 7.1 "Eigenvectors".](https://minireference.com/static/excerpts/noBSLA_v2_preview.pdf)
#
# ---
#
# [Previous: Eigenvalue](./01_eigenvalue.ipynb) | [Next: Eigenspace](./03_eigenspace.ipynb)
#
# ---
