# %% [markdown]
# ### 1.1.7.1. Eigenvalue

# %% [markdown]
# $$
# A \mathbf{e}_{\lambda} = \lambda \mathbf{e}_{\lambda}
# $$
#
# $$
# p(\lambda) = \det(A - \lambda I) = 0
# $$

# %% [markdown]
# **Explanation:**
#
# An eigenvalue is the scalar that measures how a matrix stretches a special input direction. Savov introduces the eigenvalue through the characteristic polynomial, so this notebook keeps the focus on the scalar part of the eigenpair and leaves the vector part to the next notebook on [eigenvectors](./02_eigenvector.ipynb).
#
# **Example:**
#
# For
#
# $$
# A =
# \begin{bmatrix}
# 9 & -2 \\
# -2 & 6
# \end{bmatrix},
# $$
#
# the characteristic equation gives the eigenvalues $5$ and $10$.

# %%
import sympy as sp

matrix_a = sp.Matrix([[9, -2], [-2, 6]])
symbol_lambda = sp.symbols("symbol_lambda")
characteristic_polynomial = sp.expand((matrix_a - symbol_lambda * sp.eye(2)).det())
eigenvalues = sp.solve(sp.Eq(characteristic_polynomial, 0), symbol_lambda)

print("characteristic_polynomial =", characteristic_polynomial)
print("eigenvalues =", eigenvalues)

# %% [markdown]
# **References:**
#
# [Savov, I. (2016). *No Bullshit Guide to Linear Algebra*, Section 7.1 "Eigenvalues".](https://minireference.com/static/excerpts/noBSLA_v2_preview.pdf)
#
# ---
#
# [Previous: Invertible Matrix Theorem](../06_Linear_Transformations/14_invertible_matrix_theorem.ipynb) | [Next: Eigenvector](./02_eigenvector.ipynb)
#
# ---
