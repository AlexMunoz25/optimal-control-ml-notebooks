# %% [markdown]
# ### 1.1.7.24. Unitary Matrix

# %% [markdown]
# $$
# U^{\mathsf{H}} U = I
# $$

# %% [markdown]
# **Explanation:**
#
# A unitary matrix is the complex analogue of an [orthogonal matrix](./11_orthogonal_matrix.ipynb). Savov introduces it as the matrix class that preserves the complex inner product and therefore preserves complex vector length. The notebook keeps only that preservation idea as the concept.
#
# **Example:**
#
# A diagonal matrix with entries of unit magnitude is unitary because each diagonal entry cancels with its complex conjugate in the Hermitian product.

# %%
import sympy as sp

matrix_u = sp.Matrix([[1, 0], [0, sp.I]])

print("unitary_check =")
sp.pprint(matrix_u.conjugate().T * matrix_u)

# %% [markdown]
# **References:**
#
# [Savov, I. (2016). *No Bullshit Guide to Linear Algebra*, Section 7.7 "Unitary matrices".](https://minireference.com/static/excerpts/noBSLA_v2_preview.pdf)
#
# ---
#
# [Previous: Complex Inner Product](./23_complex_inner_product.ipynb) | [Next: Hermitian Matrix](./25_hermitian_matrix.ipynb)
#
# ---
