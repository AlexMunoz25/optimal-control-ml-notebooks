# %% [markdown]
# ### 1.1.6.9. Projection Matrix Representation

# %% [markdown]
# $$
# M_{\Pi_{\hat{\mathbf{a}}}} = \hat{\mathbf{a}} \hat{\mathbf{a}}^{\mathsf{T}}
# $$

# %% [markdown]
# **Explanation:**
#
# Savov's projection example is the first concrete showcase for the probing procedure. The geometric meaning of projection was already defined in the notebook on [projection onto a line](../05_Geometrical_Aspects_of_Linear_Algebra/07_projection_onto_a_line.ipynb), so this notebook focuses only on the matrix form. The outer-product formula is included because Savov uses it to connect vectors and matrices cleanly.
#
# **Example:**
#
# For the line $y = x$ with unit direction
#
# $$
# \hat{\mathbf{a}} =
# \frac{1}{\sqrt{2}}
# \begin{bmatrix}
# 1 \\
# 1
# \end{bmatrix},
# $$
#
# the projection matrix is
#
# $$
# M_{\Pi_{\hat{\mathbf{a}}}} =
# \frac{1}{2}
# \begin{bmatrix}
# 1 & 1 \\
# 1 & 1
# \end{bmatrix}.
# $$

# %%
import sympy as sp

unit_direction = sp.Matrix([1, 1]) / sp.sqrt(2)
projection_matrix = sp.simplify(unit_direction * unit_direction.T)

print("projection_matrix =")
sp.pprint(projection_matrix)

# %% [markdown]
# **References:**
#
# [Savov, I. (2016). *No Bullshit Guide to Linear Algebra*, Section 6.2 "Projection matrices".](https://minireference.com/static/excerpts/noBSLA_v2_preview.pdf)
#
# ---
#
# [Previous: Affine Transformation](./08_affine_transformation.ipynb) | [Next: Reflection Matrix Representation](./10_reflection_matrix_representation.ipynb)
#
# ---
