# %% [markdown]
# ### 1.1.6.7. Invertible Linear Transformation

# %% [markdown]
# $$
# T^{-1}(T(\mathbf{v})) = \mathbf{v}
# $$
#
# $$
# \operatorname{Ker}(T) = \{ \mathbf{0} \}
# \Longleftrightarrow
# T \text{ is invertible}
# $$

# %% [markdown]
# **Explanation:**
#
# An invertible linear transformation can be undone by a reverse transformation. Savov links invertibility to the zero-kernel condition, so this notebook interprets invertibility through the earlier notebook on the [kernel](./03_kernel.ipynb) instead of restating the whole theorem. The full matrix equivalences are collected later in the [invertible matrix theorem](./14_invertible_matrix_theorem.ipynb).
#
# **Example:**
#
# A stretch matrix
#
# $$
# \begin{bmatrix}
# 2 & 0 \\
# 0 & 1
# \end{bmatrix}
# $$
#
# is invertible because no nonzero vector is sent to zero, and the inverse stretch is
#
# $$
# \begin{bmatrix}
# \frac{1}{2} & 0 \\
# 0 & 1
# \end{bmatrix}.
# $$

# %%
import sympy as sp

invertible_matrix = sp.Matrix([[2, 0], [0, 1]])
inverse_matrix = invertible_matrix.inv()

print("inverse_matrix =")
sp.pprint(inverse_matrix)
print("product_matrix =")
sp.pprint(invertible_matrix * inverse_matrix)

# %% [markdown]
# **References:**
#
# [Savov, I. (2016). *No Bullshit Guide to Linear Algebra*, Section 6.1 and Section 6.4.](https://minireference.com/static/excerpts/noBSLA_v2_preview.pdf)
#
# ---
#
# [Previous: Composition of Linear Transformations](./06_composition_of_linear_transformations.ipynb) | [Next: Affine Transformation](./08_affine_transformation.ipynb)
#
# ---
