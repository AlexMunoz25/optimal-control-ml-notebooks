# %% [markdown]
# ### 1.1.5.17. Subspace Bases via RREF

# %% [markdown]
# $$
# A \xrightarrow{\operatorname{rref}} R
# $$

# %% [markdown]
# **Explanation:**
#
# Savov's vector-space techniques reduce basis extraction to row reduction. The key idea is that pivot columns recover a basis for the column space, nonzero rows of the reduced matrix give a basis for the row space, and free-variable directions describe the null space. This notebook depends on the [fundamental spaces](./16_matrix_fundamental_spaces.ipynb) and on [reduced row echelon form](../04_Computational_Linear_Algebra/03_reduced_row_echelon_form.ipynb).
#
# **Example:**
#
# For
#
# $$
# A =
# \begin{bmatrix}
# 4 & -4 & 0 \\
# 1 & 1 & -2 \\
# 2 & -6 & 4
# \end{bmatrix},
# $$
#
# the pivot columns identify a basis of the column space, while the nonzero rows of the reduced matrix identify a basis of the row space.

# %%
from sympy import Matrix

matrix_a = Matrix([[4, -4, 0], [1, 1, -2], [2, -6, 4]])
reduced_matrix, pivot_columns = matrix_a.rref()
row_space_basis = [reduced_matrix.row(row_index) for row_index in range(reduced_matrix.rows) if any(reduced_matrix.row(row_index))]
column_space_basis = [matrix_a.col(column_index) for column_index in pivot_columns]

print("reduced_matrix =")
print(reduced_matrix)
print("pivot_columns =", pivot_columns)
print("row_space_basis =", row_space_basis)
print("column_space_basis =", column_space_basis)

# %% [markdown]
# **References:**
#
# [Savov, I. (2016). *No Bullshit Guide to Linear Algebra*, Section 5.5 "Vector space techniques".](https://minireference.com/static/excerpts/noBSLA_v2_preview.pdf)
#
# ---
#
# [Previous: Matrix Fundamental Spaces](./16_matrix_fundamental_spaces.ipynb) | [Next: Linear Transformation](../06_Linear_Transformations/01_linear_transformation.ipynb)
#
# ---
