# %% [markdown]
# ### 1.1.7.17. Singular Value Decomposition

# %% [markdown]
# $$
# A = U \Sigma V^{\mathsf{T}}
# $$

# %% [markdown]
# **Explanation:**
#
# The singular value decomposition factors a matrix into left singular directions, right singular directions, and stretching magnitudes. Unlike [eigendecomposition](./04_eigendecomposition.ipynb), it applies to rectangular matrices and is built from the spectrum of $A^{\mathsf{T}} A$.
#
# **Example:**
#
# For any real matrix, the diagonal entries of $\Sigma$ are the singular values, which are the square roots of the eigenvalues of $A^{\mathsf{T}} A$.

# %%
import numpy as np

matrix_a = np.array([[2.0, 1.0], [1.0, 2.0]])
matrix_u, singular_values, matrix_v_transpose = np.linalg.svd(matrix_a)

print("matrix_u =")
print(np.round(matrix_u, 4))
print("singular_values =", np.round(singular_values, 4))
print("matrix_v_transpose =")
print(np.round(matrix_v_transpose, 4))
# Out:
# matrix_u =
# [[-0.7071 -0.7071]
#  [-0.7071  0.7071]]
# singular_values = [3. 1.]
# matrix_v_transpose =
# [[-0.7071 -0.7071]
#  [-0.7071  0.7071]]

# %% [markdown]
# **References:**
#
# [Savov, I. (2016). *No Bullshit Guide to Linear Algebra*, Section 7.6 "Singular value decomposition".](https://minireference.com/static/excerpts/noBSLA_v2_preview.pdf)
#
# ---
#
# [Previous: Gram-Schmidt Orthogonalization](./16_gram_schmidt_orthogonalization.ipynb) | [Next: LU Decomposition](./18_lu_decomposition.ipynb)
#
# ---
