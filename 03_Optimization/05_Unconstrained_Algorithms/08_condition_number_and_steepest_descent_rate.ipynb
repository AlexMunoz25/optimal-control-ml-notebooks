# %% [markdown]
# ### 3.5.8. Condition Number and Steepest Descent Rate

# %% [markdown]
# $$
# \kappa(Q)=\frac{M}{m},
# \qquad
# \frac{\|x^{k+1}\|}{\|x^k\|}
# \le \max\{|1-\alpha^k m|,|1-\alpha^k M|\},
# \qquad
# \alpha^*=\frac{2}{M+m}.
# $$

# %% [markdown]
# **Explanation:**
#
# For a [positive definite](../../01_Foundations/01_Linear_Algebra/07_Theoretical_Linear_Algebra/17_positive_definite_matrix.ipynb) quadratic, the rate of steepest descent is governed by the smallest and largest [eigenvalues](../../01_Foundations/01_Linear_Algebra/07_Theoretical_Linear_Algebra/08_eigenvalue.ipynb) of the Hessian matrix $Q$. Their ratio is the [condition number](../../01_Foundations/01_Linear_Algebra/07_Theoretical_Linear_Algebra/31_condition_number.ipynb), and a large ratio means the level sets are elongated. In such a geometry, the negative gradient tends to point across the narrow direction of the valley, producing the familiar zig-zag behavior. The contraction bound in the definition cell shows this dependence explicitly through the two endpoint [eigenvalues](../../01_Foundations/01_Linear_Algebra/07_Theoretical_Linear_Algebra/08_eigenvalue.ipynb) $m$ and $M$.
#
# The matrix $Q$ has smallest and largest curvature values $m$ and $M$, often read through [eigenvalues](../../01_Foundations/01_Linear_Algebra/07_Theoretical_Linear_Algebra/08_eigenvalue.ipynb). Their ratio $\kappa(Q)=M/m$ is the [condition number](../../01_Foundations/01_Linear_Algebra/07_Theoretical_Linear_Algebra/31_condition_number.ipynb), and the displayed bound shows how that ratio controls the contraction of steepest descent on a quadratic.
#
# This is one of the main places where linear algebra becomes optimization intuition. Spectral properties are not abstract decorations; they determine how quickly a first-order method can reduce error on the local quadratic model. This analysis motivates scaling, preconditioning, Newton's method, and quasi-Newton methods.
#
# **Intuition:**
#
# The first figure shows the stepsize that minimizes the worst-case contraction bound. The second shows that the bound is sharp for certain starting points, so slow convergence is not just a proof artifact. The Kantorovich figure connects the line-search rate result to eigenvalue geometry. The code cell computes the optimal constant stepsize and the associated contraction factor from $m$ and $M$.
#
# <img src="../../Figures/030508_berts_fig_1_3_1_steepest_descent_rate_bound.jpeg" alt="Bertsekas Figure 1.3.1: steepest descent rate bound as a function of stepsize" style="width: 60%; height: auto;">
#
# <img src="../../Figures/030508_berts_fig_1_3_2_ill_conditioned_steepest_descent.jpeg" alt="Bertsekas Figure 1.3.2: sharp slow convergence example for steepest descent" style="width: 60%; height: auto;">
#
# <img src="../../Figures/030508_berts_fig_1_3_3_kantorovich_inequality.jpeg" alt="Bertsekas Figure 1.3.3: geometry behind the Kantorovich inequality" style="width: 60%; height: auto;">

# %% [markdown]
# **Numerical Example:**
#
# The rate-bound figure depends only on the endpoint eigenvalues. Take
# $$
# m=1,
# \qquad M=30.
# $$
#
# The condition number is
# $$
# \kappa(Q)=\frac{M}{m}=\frac{30}{1}=30.
# $$
#
# The constant stepsize that minimizes the worst endpoint contraction is
# $$
# \alpha^*=\frac{2}{M+m}=\frac{2}{30+1}=\frac{2}{31}\approx 0.0645.
# $$
#
# The associated contraction bound is
# $$
# \frac{\kappa-1}{\kappa+1}=\frac{30-1}{30+1}=\frac{29}{31}\approx 0.9355.
# $$
#
# A bound close to $1$ means that an ill-conditioned quadratic can reduce the error very slowly under steepest descent.

# %%
smallest_eigenvalue = 1.0
largest_eigenvalue = 30.0
optimal_stepsize = 2.0 / (smallest_eigenvalue + largest_eigenvalue)
condition_number = largest_eigenvalue / smallest_eigenvalue
contraction_bound = (condition_number - 1.0) / (condition_number + 1.0)

print("optimal_stepsize =", optimal_stepsize)
print("condition_number =", condition_number)
print("contraction_bound =", contraction_bound)
# Out:
# optimal_stepsize = 0.06451612903225806
# condition_number = 30.0
# contraction_bound = 0.9354838709677419

# %% [markdown]
# **References:**
#
# [📘 Bertsekas, D. P. (1999). *Nonlinear Programming* (2nd ed.), Chapter 1 "Unconstrained Optimization". Athena Scientific.](https://www.athenasc.com/nonlinbook.html)
#
# ---
#
# [⬅️ Previous: Rate of Convergence Concepts](./07_rate_of_convergence_concepts.ipynb) | [Next: Steepest Descent in General Norms ➡️](./09_steepest_descent_in_general_norms.ipynb)
#
# ---
