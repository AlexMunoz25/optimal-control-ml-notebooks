# %% [markdown]
# ### 3.2.10.1. Equality Constrained Convex Quadratic Problems

# %% [markdown]
# $$\min_x\frac12x^TPx+q^Tx+r\quad\text{subject to}\quad Ax=b$$

# %% [markdown]
# **Explanation:**
#
# Equality constrained convex quadratic problems lead to linear KKT equations. The multiplier enforces the equality constraint while stationarity balances the objective gradient. Feasibility is the equality equation; optimality is stationarity plus feasibility.
#
# The objective contains a quadratic form with matrix $P$, a linear term $q^Tx$, and scalar $r$. The equality constraint $Ax=b$ uses a [matrix-vector product](../../../01_Foundations/01_Linear_Algebra/03_Matrix/04_matrix_vector_multiplication.ipynb) to restrict the decision vector to an [affine set](../02_Convex_Sets/01_affine_sets_and_convex_sets.ipynb).
#
# **Properties:**
# - The Hessian gives convex curvature.
# - The equality multiplier enforces the affine constraint.
# - The KKT system couples primal variables and multipliers.
#
# **Intuition:**
#
# The example solves a two-variable quadratic with one equality constraint.

# %% [markdown]
# **Numerical Example:**
#
# Solve
# $$
# \min \frac12(x_1^2+x_2^2)
# \quad\text{subject to}\quad x_1+x_2=2.
# $$
#
# The Lagrangian stationarity equations are
# $$
# x_1+\nu=0,
# \qquad
# x_2+\nu=0.
# $$
#
# So $x_1=x_2=-\nu$. Substitute into the equality constraint:
# $$
# -\nu-\nu=2 \quad\Longrightarrow\quad \nu=-1.
# $$
#
# Therefore $x_1=x_2=1$.

# %%
import sympy as sp

variable_1, variable_2, multiplier = sp.symbols('x_1 x_2 nu')
solution = sp.solve([sp.Eq(variable_1 + multiplier, 0), sp.Eq(variable_2 + multiplier, 0), sp.Eq(variable_1 + variable_2, 2)], [variable_1, variable_2, multiplier])

print("solution =", solution)
# Out:
# solution = {nu: -1, x_1: 1, x_2: 1}

# %% [markdown]
# **Equivalent `casadi` implementation:**

# %%
import casadi as ca

opti = ca.Opti()
decision_variable = opti.variable(2)
opti.minimize(0.5 * ca.dot(decision_variable, decision_variable))
opti.subject_to(decision_variable[0] + decision_variable[1] == 2)
opti.solver("ipopt", {"print_time": False}, {"print_level": 0, "sb": "yes"})
solution = opti.solve()

print("minimizer =", ca.DM(solution.value(decision_variable)))
# Out:
# minimizer = [1, 1]

# %% [markdown]
# **References:**
#
# [📘 Boyd, S., & Vandenberghe, L. (2004). *Convex Optimization*. Cambridge University Press.](https://web.stanford.edu/~boyd/cvxbook/)
#
# ---
#
# [⬅️ Previous: Structured Newton Systems and Implementation](../09_Unconstrained_Minimization/08_structured_newton_systems_and_implementation.ipynb) | [Next: Eliminating Equality Constraints ➡️](./02_eliminating_equality_constraints.ipynb)
#
# ---
