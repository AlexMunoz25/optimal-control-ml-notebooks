# %% [markdown]
# ### 3.9.12. Newton Step, Newton Decrement, and Affine Invariance

# %% [markdown]
# $$\Delta x_{\rm nt}=-\nabla^2f(x)^{-1}\nabla f(x)$$

# %% [markdown]
# **Explanation:**
#
# The Newton step minimizes the local quadratic approximation of a twice differentiable [convex function](../03_Convex_Optimization/12_convex_function_definition_and_examples.ipynb). The Hessian supplies the local curvature metric, and the Newton decrement measures predicted decrease. Feasibility is unconstrained here; optimality is approached by solving a linear system.
#
# The Newton step multiplies the gradient by the inverse Hessian and changes sign. The Hessian inverse is a [matrix inverse](../../01_Foundations/01_Linear_Algebra/03_Matrix/11_matrix_inverse.ipynb), so the step rescales the gradient by local curvature before moving downhill.
#
# **Properties:**
# - The step solves a Hessian-gradient system.
# - The decrement is a curvature-scaled gradient [norm](../../01_Foundations/01_Linear_Algebra/02_Vector/06_vector_norm.ipynb).
# - Newton geometry explains affine invariance.
#
# **Intuition:**
#
# The figure above shows local quadratic geometry; the arithmetic solves one local Newton system.
#
# <img src="../../Figures/030512_bv_fig_9_17_newton_step_hessian_norm.jpeg" alt="Boyd and Vandenberghe Figure 9.17: Newton step as steepest descent in Hessian norm" style="width: 60%; height: auto;">

# %% [markdown]
# **Numerical Example:**
#
# The figure above shows local quadratic geometry; the arithmetic solves one local Newton system.
#
# Let
# $$
# \nabla f=\begin{bmatrix}2\\4\end{bmatrix},\quad
# \nabla^2 f=\begin{bmatrix}2&0\\0&4\end{bmatrix}.
# $$
#
# The Newton equation is
# $$
# \nabla^2 f\,\Delta x=-\nabla f.
# $$
#
# Thus
# $$
# 2\Delta x_1=-2 \Rightarrow \Delta x_1=-1,
# \qquad
# 4\Delta x_2=-4 \Rightarrow \Delta x_2=-1.
# $$
#
# The squared decrement is
# $$
# \frac{2^2}{2}+\frac{4^2}{4}=2+4=6.
# $$

# %%
import sympy as sp

gradient = sp.Matrix([2, 4])
hessian = sp.diag(2, 4)
step = -hessian.inv() * gradient

decrement_squared = (gradient.T * hessian.inv() * gradient)[0]

print("step =", step)
print("decrement_squared =", decrement_squared)
# Out:
# step = Matrix([[-1], [-1]])
# decrement_squared = 6

# %% [markdown]
# **Equivalent `casadi` implementation:**

# %%
import casadi as ca

gradient = ca.DM([2, 4])
hessian = ca.DM([[2, 0], [0, 4]])
step = -ca.solve(hessian, gradient)
decrement_squared = ca.bilin(ca.inv(hessian), gradient, gradient)

print("step =", step)
print("decrement_squared =", decrement_squared)
# Out:
# step = [-1, -1]
# decrement_squared = 6

# %% [markdown]
# **References:**
#
# [📘 Boyd, S., & Vandenberghe, L. (2004). *Convex Optimization*. Cambridge University Press.](https://web.stanford.edu/~boyd/cvxbook/)
#
# ---
#
# [⬅️ Previous: Newton's Method](./11_newtons_method.ipynb) | [Next: Newton Convergence for Convex Functions ➡️](./13_newton_convergence_for_convex_functions.ipynb)
#
# ---
