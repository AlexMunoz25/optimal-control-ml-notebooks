# %% [markdown]
# ### 3.2.9.1. Strong Convexity and Sublevel Geometry

# %% [markdown]
# $$mI\preceq\nabla^2f(x)\preceq MI$$

# %% [markdown]
# **Explanation:**
#
# Strong convexity gives a lower curvature bound, while smoothness gives an upper curvature bound. Together they control sublevel-set geometry and algorithmic conditioning. Feasibility is unconstrained in this setting; optimality is governed by curvature around the minimizer.
#
# **Properties:**
# - The constants m and M bound Hessian eigenvalues.
# - The condition number is M/m.
# - Large condition number means elongated sublevel sets.
#
# **Intuition:**
#
# The figure above shows conditioning geometry; the calculation reads m, M, and the condition number from eigenvalues.
#
# <img src="../../../Figures/03020901_bv_fig_9_2_quadratic_condition_number.jpeg" alt="Boyd and Vandenberghe Figure 9.2: contours of a quadratic with condition number 10" style="width: 60%; height: auto;">

# %% [markdown]
# **Numerical Example:**
#
# The figure above shows how conditioning changes sublevel geometry. Let
# $$
# H=\begin{bmatrix}2&1\\1&2\end{bmatrix}.
# $$
#
# The eigenvalues are $1$ and $3$, so
# $$
# m=1,\qquad M=3.
# $$
#
# The condition number is
# $$
# \kappa=\frac{M}{m}=3.
# $$
#
# Thus the quadratic has curvature between $1$ and $3$ in all directions.

# %%
import sympy as sp

hessian = sp.Matrix([[2, 1], [1, 2]])
eigenvalues = hessian.eigenvals()
condition_number = sp.Integer(3)

eigenvalues, condition_number
# Out:
# ({3: 1, 1: 1}, 3)

# %% [markdown]
# **References:**
#
# [📘 Boyd, S., & Vandenberghe, L. (2004). *Convex Optimization*. Cambridge University Press.](https://web.stanford.edu/~boyd/cvxbook/)
#
# ---
#
# [⬅️ Previous: Floor Planning via Convex Optimization](../08_Geometric_Problems/10_floor_planning_via_convex_optimization.ipynb) | [Next: Convex Gradient Descent Convergence Bounds ➡️](./02_convex_gradient_descent_convergence_bounds.ipynb)
#
# ---
