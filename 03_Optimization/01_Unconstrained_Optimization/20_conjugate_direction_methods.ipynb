# %% [markdown]
# ### 3.1.20. Conjugate Direction Methods

# %% [markdown]
# $$
# d_i^{\mathsf T}Qd_j=0\quad (i\ne j),
# \qquad
# x^{k+1}=x^k+\alpha^k d^k,
# \qquad
# \alpha^k=-\frac{\nabla f(x^k)^{\mathsf T}d^k}{d^{k\mathsf T}Qd^k}.
# $$

# %% [markdown]
# **Explanation:**
#
# Conjugate direction methods are designed for positive definite quadratic costs. Ordinary orthogonal directions are natural for a spherical quadratic, but an elliptical quadratic has a different geometry determined by $Q$. Directions are $Q$-conjugate when they are orthogonal under the [inner product](../../01_Foundations/01_Linear_Algebra/07_Theoretical_Linear_Algebra/02_inner_product_space.ipynb) induced by $Q$, and exact minimization along $n$ such directions reaches the quadratic minimizer in at most $n$ steps. This generalizes the idea of [orthogonality](../../01_Foundations/01_Linear_Algebra/02_Vector/07_vector_orthogonality_condition.ipynb) to the geometry of the objective.
#
# The condition $d_i^{\mathsf T}Qd_j=0$ says distinct directions are conjugate with respect to the quadratic-form matrix $Q$. The update moves along one such direction, and the formula for $\alpha^k$ chooses the exact minimizer along that line for a quadratic cost.
#
# This topic shows how choosing better directions can eliminate the zig-zagging of steepest descent. The method is still based on line minimization, but each new direction is constructed so that progress made along previous directions is not undone. This is the finite-dimensional geometric heart of conjugate gradient.
#
# **Intuition:**
#
# The first figure explains conjugate directions by transforming an ordinary orthogonal-coordinate minimization into the coordinates of a quadratic. The second shows a [Gram-Schmidt orthogonalization](../../01_Foundations/01_Linear_Algebra/07_Theoretical_Linear_Algebra/07_gram_schmidt_orthogonalization.ipynb)-like construction, but with the $Q$-inner product replacing the Euclidean one. The code cell builds a second direction that is conjugate to the first for a small [positive definite matrix](../../01_Foundations/01_Linear_Algebra/07_Theoretical_Linear_Algebra/17_positive_definite_matrix.ipynb).
#
# <img src="../../Figures/030101_berts_fig_1_6_1_conjugate_direction_geometry.jpeg" alt="Bertsekas Figure 1.6.1: geometry of conjugate direction methods" style="width: 60%; height: auto;">
#
# <img src="../../Figures/030101_berts_fig_1_6_2_q_conjugate_gram_schmidt.jpeg" alt="Bertsekas Figure 1.6.2: Gram-Schmidt generation of Q-conjugate directions" style="width: 60%; height: auto;">

# %% [markdown]
# **Numerical Example:**
#
# The conjugate-direction figure replaces ordinary orthogonality by $Q$-orthogonality. Let
# $$
# Q=\begin{bmatrix}4&1\\1&3\end{bmatrix},
# \qquad d_1=\begin{bmatrix}1\\0\end{bmatrix},
# \qquad v=\begin{bmatrix}0\\1\end{bmatrix}.
# $$
#
# Remove the $Q$-component of $v$ in the $d_1$ direction:
# $$
# d_2=v-\frac{v^{\mathsf T}Qd_1}{d_1^{\mathsf T}Qd_1}d_1.
# $$
#
# Compute the scalar terms:
# $$
# Qd_1=\begin{bmatrix}4\\1\end{bmatrix},
# \qquad v^{\mathsf T}Qd_1=1,
# \qquad d_1^{\mathsf T}Qd_1=4.
# $$
#
# Thus
# $$
# d_2=\begin{bmatrix}0\\1\end{bmatrix}-\frac{1}{4}\begin{bmatrix}1\\0\end{bmatrix}
# =\begin{bmatrix}-1/4\\1\end{bmatrix}.
# $$
#
# Finally,
# $$
# d_1^{\mathsf T}Qd_2
# =\begin{bmatrix}1&0\end{bmatrix}
# \begin{bmatrix}4&1\\1&3\end{bmatrix}
# \begin{bmatrix}-1/4\\1\end{bmatrix}
# =\begin{bmatrix}1&0\end{bmatrix}
# \begin{bmatrix}0\\11/4\end{bmatrix}=0.
# $$

# %%
import numpy as np

Q = np.array([[4.0, 1.0], [1.0, 3.0]])
first_direction = np.array([1.0, 0.0])
trial_direction = np.array([0.0, 1.0])
second_direction = trial_direction - (trial_direction @ Q @ first_direction) / (first_direction @ Q @ first_direction) * first_direction
conjugacy_check = first_direction @ Q @ second_direction

print("second_direction =", second_direction)
print("conjugacy_check =", conjugacy_check)
# Out:
# second_direction = [-0.25  1.  ]
# conjugacy_check = 0.0

# %% [markdown]
# **References:**
#
# [📘 Bertsekas, D. P. (1999). *Nonlinear Programming* (2nd ed.), Chapter 1 "Unconstrained Optimization". Athena Scientific.](https://www.athenasc.com/nonlinbook.html)
#
# ---
#
# [⬅️ Previous: Incremental Gauss-Newton and Filtering](./19_incremental_gauss_newton_and_filtering.ipynb) | [Next: Conjugate Gradient Method ➡️](./21_conjugate_gradient_method.ipynb)
#
# ---
