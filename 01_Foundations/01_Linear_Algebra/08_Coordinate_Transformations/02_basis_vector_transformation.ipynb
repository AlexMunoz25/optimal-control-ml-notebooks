# %% [markdown]
# ### 1.1.8.2. Basis-Vector Transformation

# %% [markdown]
# $$
# \begin{pmatrix}
# \text{New basis} \\
# \text{vectors}
# \end{pmatrix}
# =
# \begin{pmatrix}
# \text{Direct} \\
# \text{transformation} \\
# \text{matrix}
# \end{pmatrix}
# \begin{pmatrix}
# \text{Original basis} \\
# \text{vectors}
# \end{pmatrix}
# $$
#
# $$
# \begin{bmatrix}
# \hat{\mathbf{i}}'_x \\
# \hat{\mathbf{i}}'_y
# \end{bmatrix}
# =
# \begin{bmatrix}
# \cos \alpha & -\sin \alpha \\
# \sin \alpha & \cos \alpha
# \end{bmatrix}
# \begin{bmatrix}
# 1 \\
# 0
# \end{bmatrix},
# \qquad
# \begin{bmatrix}
# \hat{\mathbf{j}}'_x \\
# \hat{\mathbf{j}}'_y
# \end{bmatrix}
# =
# \begin{bmatrix}
# \cos \alpha & -\sin \alpha \\
# \sin \alpha & \cos \alpha
# \end{bmatrix}
# \begin{bmatrix}
# 0 \\
# 1
# \end{bmatrix}
# $$

# %% [markdown]
# **Explanation:**
#
# A basis-vector transformation rotates the basis directions themselves and then expresses those new basis vectors in the original coordinate system. The direct transformation matrix therefore acts on the old basis vectors to produce the new basis. For an orthogonal rotation, the columns of that matrix are exactly the rotated basis vectors written in the original frame.
#
# <p align="center">
#   <img src="../../../Figures/01010801_rotated_basis_in_original_system.jpeg" alt="Rotated basis vectors expressed in the original system" width="680">
# </p>
#
# **Example:**
#
# For a $150^{\circ}$ counterclockwise rotation,
# $$
# \hat{\mathbf{i}}' =
# \begin{bmatrix}
# \cos 150^{\circ} \\
# \sin 150^{\circ}
# \end{bmatrix}
# =
# \begin{bmatrix}
# -0.866 \\
# 0.500
# \end{bmatrix},
# \qquad
# \hat{\mathbf{j}}' =
# \begin{bmatrix}
# -\sin 150^{\circ} \\
# \cos 150^{\circ}
# \end{bmatrix}
# =
# \begin{bmatrix}
# -0.500 \\
# -0.866
# \end{bmatrix}.
# $$

# %%
import sympy as sp

rotation_angle = sp.rad(150)
direct_transformation_matrix = sp.Matrix([
    [sp.cos(rotation_angle), -sp.sin(rotation_angle)],
    [sp.sin(rotation_angle), sp.cos(rotation_angle)],
])
original_basis_i = sp.Matrix([1, 0])
original_basis_j = sp.Matrix([0, 1])
rotated_basis_i = direct_transformation_matrix * original_basis_i
rotated_basis_j = direct_transformation_matrix * original_basis_j

print("direct_transformation_matrix =")
sp.pprint(direct_transformation_matrix)
print("rotated_basis_i =")
sp.pprint(rotated_basis_i)
print("rotated_basis_j =")
sp.pprint(rotated_basis_j)
# Out:
# direct_transformation_matrix =
# ⎡-√3       ⎤
# ⎢────  -1/2⎥
# ⎢ 2        ⎥
# ⎢          ⎥
# ⎢      -√3 ⎥
# ⎢1/2   ────⎥
# ⎣       2  ⎦
# rotated_basis_i =
# ⎡-√3 ⎤
# ⎢────⎥
# ⎢ 2  ⎥
# ⎢    ⎥
# ⎣1/2 ⎦
# rotated_basis_j =
# ⎡-1/2⎤
# ⎢    ⎥
# ⎢-√3 ⎥
# ⎢────⎥
# ⎣ 2  ⎦

# %% [markdown]
# **References:**
#
# [📘 D. Fleisch. (2012). *A Student's Guide to Vectors and Tensors*](https://web.unica.it/static/resources/cms/documents/FleischVectorsAndTensors.pdf)
#
# ---
#
# [⬅️ Previous: Coordinate-System Transformation](./01_coordinate_system_transformation.ipynb) | [Next: Passive Transformation ➡️](./03_passive_transformation.ipynb)
