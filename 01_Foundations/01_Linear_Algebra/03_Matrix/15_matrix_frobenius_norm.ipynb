# %% [markdown]
# ### 1.1.3.15. Matrix Frobenius Norm

# %% [markdown]
# $$
# \|\mathbf{A}\|_F =
# \sqrt{\sum_{i=1}^m \sum_{j=1}^n |A_{ij}|^2}
# $$

# %% [markdown]
# **Explanation:**
#
# The Frobenius norm of a matrix $\mathbf{A} \in \mathbb{R}^{m \times n}$ is equivalent to the Euclidean norm of the vector formed by its entries.
# It equals the square root of the sum of squares of the singular values and is invariant under unitary transformations.
#
# The Frobenius norm is the matrix analogue of the [norm of a vector](../02_Vector/06_vector_norm.ipynb), and identities involving the [trace of a matrix](./17_matrix_trace.ipynb) make it a convenient case of the broader [matrix norm inequality](./16_matrix_norm_inequality.ipynb).
#
# **Example:**
#
# Let
#
# $$
# \mathbf{A} =
# \begin{bmatrix}
# 1 & 2 \\
# 3 & 4
# \end{bmatrix}.
# $$
#
# Then
#
# $$
# \|\mathbf{A}\|_F =
# \sqrt{1^2 + 2^2 + 3^2 + 4^2}
# =
# \sqrt{30}.
# $$

# %%
import sympy as sp

matrix_a = sp.Matrix([[1, 2], [3, 4]])

frobenius_norm = matrix_a.norm()

print("‖A‖_F =", frobenius_norm)
# Out:
# ‖A‖_F = 5.477225575051661

# %% [markdown]
# **References:**
#
# [📘 Aazi, M. (2024). *Mathematics For Machine Learning*](https://www.scribd.com/document/812294393/Mathematics-for-Machine-Learning)
#
# ---
#
# [⬅️ Previous: Outer Product](./14_matrix_outer_product.ipynb) | [Next: Matrix Norm Inequality ➡️](./16_matrix_norm_inequality.ipynb)
