# %% [markdown]
# ### 1.1.2.3. Scalar Multiplication of a Vector

# %% [markdown]
# $$
# \alpha \mathbf{v} = \alpha
# \begin{bmatrix}
# v_1 \\
# v_2 \\
# \vdots \\
# v_n
# \end{bmatrix}
# =
# \begin{bmatrix}
# \alpha v_1 \\
# \alpha v_2 \\
# \vdots \\
# \alpha v_n
# \end{bmatrix}
# $$

# %% [markdown]
# **Explanation:**
#
# Scalar multiplication scales each component of a vector by the same scalar. Multiplying a vector by a positive scalar changes its length but not its direction. Multiplying by a negative scalar reverses the direction in addition to scaling the length.
#
# <p align="center">
#   <img src="../../../Figures/01010203_scalar_multiplication.jpeg"
#        alt="Multiplication of a vector by a scalar"
#        width="450">
# </p>
#
# **Related concepts:**
# - Builds on [Vectors](./01_vector_definition.ipynb).
# - Combines with [Vector Addition](./02_vector_addition.ipynb) in the linear combinations used throughout [Matrix-Vector Multiplication](../03_Matrix/04_matrix_vector_multiplication.ipynb).
#
# **Example:**
#
# If
#
# $$
# \alpha = 3, \quad
# \mathbf{v} =
# \begin{bmatrix}
# 2 \\
# -1
# \end{bmatrix},
# $$
#
# then
#
# $$
# \alpha \mathbf{v} =
# \begin{bmatrix}
# 6 \\
# -3
# \end{bmatrix}.
# $$

# %%
import sympy as sp

scalar = 3
vector_v = sp.Matrix([2, -1])

result = scalar * vector_v

print("αv =", list(result))
# Out:
# αv = [ 6 -3]

# %% [markdown]
# **References:**
#
# [📘 Aazi, M. (2024). *Mathematics For Machine Learning*](https://www.scribd.com/document/812294393/Mathematics-for-Machine-Learning)
#
# [📗 Fleisch, D. (2012). *A Student's Guide to Vectors and Tensors.* Cambridge University Press.](https://www.cambridge.org/core/books/students-guide-to-vectors-and-tensors/46EB80DBBF3C1C1B06F1B9E34C6D7753)
#
# ---
#
# [⬅️ Previous: Vector Addition](./02_vector_addition.ipynb) | [Next: Dot Product ➡️](./04_vector_dot_product.ipynb)
