# %% [markdown]
# ### 3.2.5.1. Lagrangian and Dual Function

# %% [markdown]
# $$L(x,\lambda,\nu)=f_0(x)+\sum_i\lambda_if_i(x)+\sum_i\nu_ih_i(x),\quad g=\inf_xL$$

# %% [markdown]
# **Explanation:**
#
# The Lagrangian combines the objective with weighted constraint functions. Minimizing it over the primal variable produces the dual function, a lower bound for a minimization problem whenever the multipliers are dual feasible.
#
# The variable $x$ is primal, $\lambda_i$ are inequality multipliers, and $\nu_i$ are equality multipliers. The Lagrangian adds multiplier-weighted constraint functions to the objective, and $g$ is obtained by minimizing that expression over $x$.
#
# **Properties:**
# - Inequality multipliers must be nonnegative.
# - The dual function is an infimum over primal variables.
# - The lower bound can be loose unless the multiplier is optimal.
#
# **Intuition:**
#
# The calculation minimizes one scalar Lagrangian exactly.
#
# <img src="../../../Figures/03020501_bv_fig_5_1_dual_lower_bound.jpeg" alt="Boyd and Vandenberghe Figure 5.1: lower bound from a dual feasible point" style="width: 60%; height: auto;">

# %% [markdown]
# **Numerical Example:**
#
# The figure above gives the visual version of the same calculation.
#
# Consider the Lagrangian
# $$
# L(x,2)=x^2+2(x-1)=x^2+2x-2.
# $$
#
# Differentiate with respect to $x$:
# $$
# \frac{d}{dx}L(x,2)=2x+2.
# $$
#
# Set this to zero:
# $$
# 2x+2=0 \quad\Longrightarrow\quad x=-1.
# $$
#
# The dual-function value at this multiplier is
# $$
# L(-1,2)=(-1)^2+2(-1-1)=1-4=-3.
# $$
#
# This is a valid lower bound for the associated minimization problem.

# %%
import sympy as sp

variable = sp.symbols('x')
lagrangian = variable ** 2 + 2 * (variable - 1)
stationary_point = sp.solve(sp.diff(lagrangian, variable), variable)[0]
dual_value = sp.simplify(lagrangian.subs(variable, stationary_point))

print("stationary_point =", stationary_point)
print("dual_value =", dual_value)
# Out:
# stationary_point = -1
# dual_value = -3

# %% [markdown]
# **Direct `casadi` implementation:**

# %%
import casadi as ca

variable = ca.SX.sym("x")
lagrangian = variable ** 2 + 2 * (variable - 1)
gradient = ca.gradient(lagrangian, variable)
hessian = ca.jacobian(gradient, variable)
stationary_point = ca.solve(ca.evalf(hessian), -ca.evalf(ca.substitute(gradient, variable, ca.DM(0))))
dual_value = ca.evalf(ca.substitute(lagrangian, variable, stationary_point))

print("stationary_point =", stationary_point)
print("dual_value =", dual_value)
# Out:
# stationary_point = -1
# dual_value = -3

# %% [markdown]
# **References:**
#
# [📘 Boyd, S., & Vandenberghe, L. (2004). *Convex Optimization*. Cambridge University Press.](https://web.stanford.edu/~boyd/cvxbook/)
#
# ---
#
# [⬅️ Previous: Vector and Multicriterion Optimization](../04_Convex_Optimization_Problems/12_vector_and_multicriterion_optimization.ipynb) | [Next: Dual Problem and Weak Duality ➡️](./02_dual_problem_and_weak_duality.ipynb)
#
# ---
