# %% [markdown]
# ### 1.1.3.1. Matrices

# %% [markdown]
# $$
# A =
# \begin{bmatrix}
# 0 & 1 & -2.3 & 0.1 \\
# 1.3 & 4 & -0.1 & 0 \\
# 4.1 & -1 & 0 & 1.7
# \end{bmatrix}
# $$

# %% [markdown]
# **Explanation:**
#
# A **matrix** is a rectangular array of numbers. The **size** is given by the number of rows and columns ($m \times n$).
# Each entry $A_{ij}$ is identified by its row index $i$ and column index $j$.
#
# **Matrix types:**
# - **Square matrix**: same number of rows and columns ($n \times n$)
# - **Tall matrix**: more rows than columns ($m > n$)
# - **Wide matrix**: more columns than rows ($n > m$)
#
# An $m \times n$ matrix can be viewed as columns concatenated or rows stacked.
# A **submatrix** $A_{p:q,\,r:s}$ is formed by selecting specific rows and columns.
#
# A matrix can be read as a collection of [vectors](../02_Vector/01_vector_definition.ipynb) whose entries come from familiar number [sets](../01_Prerequisites/01_sets.ipynb). That viewpoint becomes concrete in [matrix-vector multiplication](./04_matrix_vector_multiplication.ipynb) and in the coefficient arrays used for an [augmented matrix](../04_Computational_Linear_Algebra/01_augmented_matrix.ipynb).
#
# **Example:**
#
# If
#
# $$
# B =
# \begin{bmatrix}
# 0 & 1 & -2.3 & 0.1 \\
# 1.3 & 4 & -0.1 & 0 \\
# 4.1 & -1 & 0 & 1.7
# \end{bmatrix},
# $$
#
# then $B_{13} = -2.3$, $B_{32} = -1$.

# %%
import numpy as np

matrix_a = np.array([
    [0, 1, -2.3, 0.1],
    [1.3, 4, -0.1, 0],
    [4.1, -1, 0, 1.7]
])

print("Matrix A:\n", matrix_a)
print("\nShape (rows × cols):", matrix_a.shape)
print("\nA[1,3] =", matrix_a[0, 2])
print("A[3,2] =", matrix_a[2, 1])
print("\nFirst row:", matrix_a[0, :])
print("Second column:\n", matrix_a[:, 1])
print("\nSubmatrix A[2:3, 3:4]:\n", matrix_a[1:3, 2:4])
# Out:
# Matrix A:
#  [[ 0.   1.  -2.3  0.1]
#  [ 1.3  4.  -0.1  0. ]
#  [ 4.1 -1.   0.   1.7]]
#
# Shape (rows × cols): (3, 4)
#
# A[1,3] = -2.3
# A[3,2] = -1.0
#
# First row: [ 0.   1.  -2.3  0.1]
# Second column:
#  [ 1.  4. -1.]
#
# Submatrix A[2:3, 3:4]:
#  [[-0.1  0. ]
#  [ 0.   1.7]]

# %% [markdown]
# **References:**
#
#
# [📘 Boyd, S., & Vandenberghe, L. (2018). *Introduction to Applied Linear Algebra: Vectors, Matrices, and Least Squares.*](https://web.stanford.edu/~boyd/vmls/)
#
#
#
# ---
#
#
#
# [⬅️ Previous: Triple Vector Product](../02_Vector/09_vector_triple_vector_product.ipynb) | [Next: Matrix Addition ➡️](./02_matrix_addition.ipynb)
