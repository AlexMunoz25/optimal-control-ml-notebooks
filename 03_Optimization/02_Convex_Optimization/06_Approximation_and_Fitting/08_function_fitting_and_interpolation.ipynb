# %% [markdown]
# ### 3.2.6.8. Function Fitting and Interpolation

# %% [markdown]
# $$\min_\theta\|A\theta-y\|$$

# %% [markdown]
# **Explanation:**
#
# Function fitting chooses parameters so a model agrees with sampled data as well as possible. Convex losses and affine parameterizations give convex fitting problems, while interpolation imposes exact agreement constraints.
#
# The parameter vector $\theta$ is the decision variable. The matrix $A$ evaluates the basis or model at sample points, $y$ is the data vector, and the objective minimizes the residual [norm](../../../01_Foundations/01_Linear_Algebra/02_Vector/06_vector_norm.ipynb) $A\theta-y$.
#
# **Properties:**
# - Residuals measure mismatch between a model and data.
# - Squaring residuals gives a smooth convex objective.
# - The derivative or normal equations give the optimality condition.
#
# **Intuition:**
#
# The computation expands the residual objective so the convex quadratic structure is visible before solving.

# %% [markdown]
# **Numerical Example:**
#
# Let $r_1(x)=x-1$ and $r_2(x)=2x-3$. The least-squares objective is
# $$
# f(x)=(x-1)^2+(2x-3)^2.
# $$
#
# Expand it:
# $$
# f(x)=x^2-2x+1+4x^2-12x+9=5x^2-14x+10.
# $$
#
# Differentiate and set the derivative to zero:
# $$
# f'(x)=10x-14=0.
# $$
#
# Thus
# $$
# x^\star=\frac{14}{10}=\frac75.
# $$
#
# The minimum value is
# $$
# f(7/5)=(2/5)^2+(-1/5)^2=\frac15.
# $$

# %%
import sympy as sp

variable = sp.symbols('x')
objective = (variable - 1) ** 2 + (2 * variable - 3) ** 2
optimizer = sp.solve(sp.diff(objective, variable), variable)[0]
minimum_value = sp.simplify(objective.subs(variable, optimizer))

print("optimizer =", optimizer)
print("minimum_value =", minimum_value)
# Out:
# optimizer = 7/5
# minimum_value = 1/5

# %% [markdown]
# **Direct `casadi` implementation:**

# %%
import casadi as ca

variable = ca.SX.sym("x")
objective = (variable - 1) ** 2 + (2 * variable - 3) ** 2
gradient = ca.gradient(objective, variable)
hessian = ca.jacobian(gradient, variable)
optimizer = ca.solve(ca.evalf(hessian), -ca.evalf(ca.substitute(gradient, variable, ca.DM(0))))
minimum_value = ca.evalf(ca.substitute(objective, variable, optimizer))

print("optimizer =", optimizer)
print("minimum_value =", minimum_value)
# Out:
# optimizer = 1.4
# minimum_value = 0.2

# %% [markdown]
# **References:**
#
# [📘 Boyd, S., & Vandenberghe, L. (2004). *Convex Optimization*. Cambridge University Press.](https://web.stanford.edu/~boyd/cvxbook/)
#
# ---
#
# [⬅️ Previous: Robust Approximation Models](./07_robust_approximation_models.ipynb) | [Next: Basis Pursuit and Sparse Descriptions ➡️](./09_basis_pursuit_and_sparse_descriptions.ipynb)
#
# ---
