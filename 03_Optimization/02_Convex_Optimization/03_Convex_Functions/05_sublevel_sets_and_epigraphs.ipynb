# %% [markdown]
# ### 3.2.3.5. Sublevel Sets and Epigraphs

# %% [markdown]
# $$C_\alpha=\{x\mid f(x)\leq\alpha\},\qquad\operatorname{epi}f=\{(x,t)\mid f(x)\leq t\}$$

# %% [markdown]
# **Explanation:**
#
# Sublevel sets and epigraphs translate function inequalities into geometry. A sublevel set keeps points below a specified value, while an epigraph records all points above the graph of the function.
#
# The sublevel set $C_\alpha$ contains points whose function value is at most the level $\alpha$. The epigraph contains pairs $(x,t)$ where the height $t$ is at least $f(x)$, so it records the region above the graph.
#
# **Properties:**
# - [Convex functions](01_convex_function_definition_and_examples.ipynb) have convex epigraphs.
# - Quasiconvex functions have convex sublevel sets.
# - Epigraph transformations replace objectives by constraints.
#
# **Intuition:**
#
# The figure above shows set membership derived from a function value; the arithmetic checks that membership.
#
# <img src="../../../Figures/03020305_bv_fig_3_5_epigraph.jpeg" alt="Boyd and Vandenberghe Figure 3.5: epigraph of a function" style="width: 60%; height: auto;">

# %% [markdown]
# **Numerical Example:**
#
# The figure above shows set membership derived from a function value; the arithmetic checks that membership.
#
# Let $f(x)=x^2$ and $x=2$. First compute
# $$
# f(2)=2^2=4.
# $$
#
# At level $5$,
# $$
# 4\leq5,
# $$
# so $x=2$ is in the sublevel set. At level $3$,
# $$
# 4\leq3
# $$
# is false, so $x=2$ is not in that lower sublevel set.

# %%
import sympy as sp

function_value = sp.Integer(2) ** 2

print("function_value <= 5 =", function_value <= 5)
print("function_value <= 3 =", function_value <= 3)
# Out:
# function_value <= 5 = True
# function_value <= 3 = False

# %% [markdown]
# **References:**
#
# [📘 Boyd, S., & Vandenberghe, L. (2004). *Convex Optimization*. Cambridge University Press.](https://web.stanford.edu/~boyd/cvxbook/)
#
# ---
#
# [⬅️ Previous: Second-Order Convexity Condition](./04_second_order_convexity_condition.ipynb) | [Next: Jensen Inequality and Convex Inequalities ➡️](./06_jensens_inequality_and_convex_inequalities.ipynb)
#
# ---
