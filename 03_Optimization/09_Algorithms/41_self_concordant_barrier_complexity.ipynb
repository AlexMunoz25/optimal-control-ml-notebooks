# %% [markdown]
# ### 3.9.41. Self-Concordant Barrier Complexity

# %% [markdown]
# $$N=O(\sqrt m\log(1/\epsilon))$$

# %% [markdown]
# **Explanation:**
#
# Self-concordant barrier theory gives iteration bounds for interior-point methods. The dependence on accuracy is logarithmic, while the barrier parameter contributes through a square-root factor. Feasibility is maintained in the strict interior; optimality is measured by the target gap.
#
# The symbol $N$ denotes an iteration bound, $m$ is the number of inequalities, and $\epsilon$ is the target accuracy. The big-O expression says the dependence on the number of inequalities is through $\sqrt m$, while the dependence on accuracy is logarithmic.
#
# **Properties:**
# - The iteration bound scales like sqrt(m) log(1/epsilon).
# - The accuracy dependence is logarithmic.
# - The result explains reliable performance of barrier methods.
#
# **Intuition:**
#
# The example evaluates the symbolic complexity expression.

# %% [markdown]
# **Numerical Example:**
#
# Use the expression
# $$
# \sqrt{m}\log(1/\epsilon)
# $$
# with $m=16$ and $\epsilon=10^{-3}$.
#
# First,
# $$
# \sqrt{16}=4.
# $$
#
# Also,
# $$
# \log(1/\epsilon)=\log(1000).
# $$
#
# Therefore the expression is
# $$
# 4\log(1000).
# $$

# %%
import sympy as sp

constraint_count = sp.Integer(16)
accuracy = sp.Rational(1, 1000)
complexity_expression = sp.sqrt(constraint_count) * sp.log(1 / accuracy)

print("complexity_expression =", complexity_expression)
# Out:
# complexity_expression = 4*log(1000)

# %% [markdown]
# **References:**
#
# [📘 Boyd, S., & Vandenberghe, L. (2004). *Convex Optimization*. Cambridge University Press.](https://web.stanford.edu/~boyd/cvxbook/)
#
# ---
#
# [⬅️ Previous: Phase I Feasibility Methods](./40_phase_i_feasibility_methods.ipynb) | [Next: Generalized Inequality Barriers ➡️](./42_generalized_inequality_barriers.ipynb)
#
# ---
