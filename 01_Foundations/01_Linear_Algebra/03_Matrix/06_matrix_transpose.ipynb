# %% [markdown]
# ### 1.1.3.6. Transpose of a Matrix

# %% [markdown]
# $$
# \mathbf{A}^T =
# \begin{bmatrix}
# a_{11} & a_{12} \\
# a_{21} & a_{22}
# \end{bmatrix}^T
# =
# \begin{bmatrix}
# a_{11} & a_{21} \\
# a_{12} & a_{22}
# \end{bmatrix}
# $$

# %% [markdown]
# **Explanation:**
#
# The transpose of a matrix flips it over its diagonal, exchanging rows with columns.
# It is used in ML for switching between data representations.
#
# For a [matrix](./01_matrix_definition.ipynb), transposition swaps the row and column viewpoints, which is why it reappears in [trace](./17_matrix_trace.ipynb) identities and in the formulas for the [trace of a matrix product](./18_matrix_trace_of_product.ipynb).
#
# **Example:**
#
# If
#
# $$
# \mathbf{A} =
# \begin{bmatrix}
# 1 & 2 \\
# 3 & 4
# \end{bmatrix},
# $$
#
# then
#
# $$
# \mathbf{A}^T =
# \begin{bmatrix}
# 1 & 3 \\
# 2 & 4
# \end{bmatrix}.
# $$

# %%
import sympy as sp

matrix_a = sp.Matrix([[1, 2], [3, 4]])

transposed = matrix_a.T

print("Aᵀ =")
sp.pprint(transposed)
# Out:
# Aᵀ =
#  [[1 3]
#  [2 4]]

# %% [markdown]
# **References:**
#
# [📘 Aazi, M. (2024). *Mathematics For Machine Learning*](https://www.scribd.com/document/812294393/Mathematics-for-Machine-Learning)
#
# ---
#
# [⬅️ Previous: Matrix Multiplication](./05_matrix_multiplication.ipynb) | [Next: Determinant of a 2×2 Matrix ➡️](./07_matrix_determinant_2d.ipynb)
