# %% [markdown]
# ### 3.3.3. Cones and Conic Combinations

# %% [markdown]
# $$\theta_1x_1+\cdots+\theta_kx_k,\qquad\theta_i\geq0$$

# %% [markdown]
# **Explanation:**
#
# A convex cone is closed under nonnegative linear combinations. This is the set geometry behind conic constraints and generalized inequalities. Feasibility means the combination remains inside the cone; optimality conditions later use dual cone multipliers to certify such constraints.
#
# The displayed sum is a conic combination of points or directions $x_i$. Each coefficient $\theta_i$ is nonnegative, so the combination can scale and add directions without reversing them.
#
# **Properties:**
# - Conic coefficients are nonnegative.
# - They do not need to sum to one.
# - The zero vector appears when all coefficients are zero.
#
# **Intuition:**
#
# The figure above shows the cone generated by rays; the arithmetic computes one nonnegative combination inside it.
#
# <img src="../../Figures/030203_bv_fig_2_4_conic_combination.jpeg" alt="Boyd and Vandenberghe Figure 2.4: conic combinations of two points" style="width: 60%; height: auto;">

# %% [markdown]
# **Numerical Example:**
#
# The figure above shows the cone generated by rays; the arithmetic computes one nonnegative combination inside it.
#
# Let
# $$
# v_1=\begin{bmatrix}1\\0\end{bmatrix},\quad
# v_2=\begin{bmatrix}1\\2\end{bmatrix}.
# $$
#
# Choose nonnegative coefficients $3$ and $2$. Then
# $$
# 3v_1+2v_2=3\begin{bmatrix}1\\0\end{bmatrix}+2\begin{bmatrix}1\\2\end{bmatrix}.
# $$
#
# The coordinates are
# $$
# 3\cdot1+2\cdot1=5,
# \qquad
# 3\cdot0+2\cdot2=4.
# $$
#
# So the conic combination is
# $$
# \begin{bmatrix}5\\4\end{bmatrix}.
# $$

# %%
import sympy as sp

direction_1 = sp.Matrix([1, 0])
direction_2 = sp.Matrix([1, 2])
combination = 3 * direction_1 + 2 * direction_2

print("combination =", combination)
# Out:
# combination = Matrix([[5], [4]])

# %% [markdown]
# **Equivalent `casadi` implementation:**

# %%
import casadi as ca

direction_1 = ca.DM([1, 0])
direction_2 = ca.DM([1, 2])
combination = 3 * direction_1 + 2 * direction_2

print("combination =", combination)
# Out:
# combination = [5, 4]

# %% [markdown]
# **References:**
#
# [📘 Boyd, S., & Vandenberghe, L. (2004). *Convex Optimization*. Cambridge University Press.](https://web.stanford.edu/~boyd/cvxbook/)
#
# ---
#
# [⬅️ Previous: Affine Hull, Relative Interior, and Dimension](./02_affine_hull_relative_interior_and_dimension.ipynb) | [Next: Hyperplanes, Halfspaces, Balls, and Ellipsoids ➡️](./04_hyperplanes_halfspaces_balls_and_ellipsoids.ipynb)
#
# ---
