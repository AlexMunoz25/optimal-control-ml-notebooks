# %% [markdown]
# ### 1.1.3.12. Rank-Nullity Theorem

# %% [markdown]
# $$
# \text{rank}(\mathbf{A}) + \text{nullity}(\mathbf{A}) = n
# $$

# %% [markdown]
# **Explanation:**
#
# The rank-nullity theorem states that for any linear transformation represented by a matrix $\mathbf{A}$ mapping from an $m$-dimensional domain to an $n$-dimensional codomain, the sum of rank and nullity equals $n$ (the number of columns).
#
# - **Rank**: dimension of the column space (number of linearly independent columns)
# - **Nullity**: dimension of the null space (number of free variables in solutions to $\mathbf{A}\mathbf{x} = \mathbf{0}$)
#
# Depends on [Matrix-Vector Multiplication](./04_matrix_vector_multiplication.ipynb) because nullity is defined through solutions of $A\mathbf{x} = \mathbf{0}$. It also benefits from [Reduced Row Echelon Form](../04_Computational_Linear_Algebra/03_reduced_row_echelon_form.ipynb) and supports [Number of Solutions](../04_Computational_Linear_Algebra/05_number_of_solutions.ipynb).
#
# **Example:**
#
# Consider a $3 \times 3$ matrix with rank 2. Then
#
# $$
# 2 + \text{nullity}(\mathbf{A}) = 3 \Rightarrow \text{nullity}(\mathbf{A}) = 1.
# $$

# %%
import sympy as sp

matrix_a = sp.Matrix([
    [1, 2, 3],
    [4, 5, 6],
    [7, 8, 9]
])

rank_value = matrix_a.rank()
nullity_value = matrix_a.cols - rank_value

print("rank(A) =", rank_value)
print("nullity(A) =", nullity_value)
# Out:
# rank(A) = 2
# nullity(A) = 1

# %% [markdown]
# **References:**
#
# [📘 Aazi, M. (2024). *Mathematics For Machine Learning*](https://www.scribd.com/document/812294393/Mathematics-for-Machine-Learning)
#
# ---
#
# [⬅️ Previous: Inverse of a Square Matrix](./11_matrix_inverse.ipynb) | [Next: Hadamard (Elementwise) Product ➡️](./13_matrix_elementwise_product.ipynb)
