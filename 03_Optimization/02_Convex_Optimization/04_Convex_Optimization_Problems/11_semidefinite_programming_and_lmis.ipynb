# %% [markdown]
# ### 3.2.4.11. Semidefinite Programming and LMIs

# %% [markdown]
# $$F(x)=F_0+x_1F_1+\cdots+x_nF_n\succeq0$$

# %% [markdown]
# **Explanation:**
#
# Semidefinite programs optimize a linear objective subject to affine matrix inequalities. Each linear matrix inequality requires an affine symmetric matrix to lie in the positive semidefinite cone.
#
# **Properties:**
# - All eigenvalues must be nonnegative for positive semidefiniteness.
# - Positive semidefinite matrices form a convex cone.
# - Matrix inequalities use this cone as an order relation.
#
# **Intuition:**
#
# The example checks a concrete two-by-two matrix through its eigenvalues.

# %% [markdown]
# **Numerical Example:**
#
# Let
# $$
# X=\begin{bmatrix}2&1\\1&2\end{bmatrix}.
# $$
#
# The characteristic polynomial is
# $$
# \det(X-\lambda I)=(2-\lambda)^2-1.
# $$
#
# Expanding gives
# $$
# (2-\lambda)^2-1=\lambda^2-4\lambda+3=(\lambda-1)(\lambda-3).
# $$
#
# Thus the eigenvalues are $1$ and $3$. Since both are nonnegative, $X\succeq0$.

# %%
import sympy as sp

matrix = sp.Matrix([[2, 1], [1, 2]])
eigenvalues = matrix.eigenvals()

matrix, eigenvalues
# Out:
# (Matrix([
#  [2, 1],
#  [1, 2]]),
#  {3: 1, 1: 1})

# %% [markdown]
# **References:**
#
# [📘 Boyd, S., & Vandenberghe, L. (2004). *Convex Optimization*. Cambridge University Press.](https://web.stanford.edu/~boyd/cvxbook/)
#
# ---
#
# [⬅️ Previous: Conic Form Optimization](./10_conic_form_optimization.ipynb) | [Next: Vector and Multicriterion Optimization ➡️](./12_vector_and_multicriterion_optimization.ipynb)
#
# ---
