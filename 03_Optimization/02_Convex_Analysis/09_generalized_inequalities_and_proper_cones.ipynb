# %% [markdown]
# ### 3.2.9. Generalized Inequalities and Proper Cones

# %% [markdown]
# $$x\preceq_Ky\quad\Longleftrightarrow\quad y-x\in K$$

# %% [markdown]
# **Explanation:**
#
# A [proper cone](03_cones_and_conic_combinations.ipynb) defines an order by declaring one vector larger than another when their difference lies in the cone. The nonnegative orthant gives componentwise order, while the [positive semidefinite cone](06_positive_semidefinite_cone.ipynb) gives matrix order.
#
# The cone $K$ defines the order relation. The statement $x\preceq_K y$ means that the difference $y-x$ lies in $K$, so generalized inequalities turn vector comparison into membership in a [cone](03_cones_and_conic_combinations.ipynb).
#
# **Properties:**
# - The cone defines the meaning of inequality.
# - For the nonnegative orthant, every component must be nonnegative.
# - This order supports vector optimization and conic duality.
#
# **Intuition:**
#
# The example checks cone membership by inspecting each component of a difference vector.

# %% [markdown]
# **Numerical Example:**
#
# Let
# $$
# x=\begin{bmatrix}1\\2\end{bmatrix},\quad
# y=\begin{bmatrix}3\\5\end{bmatrix},\quad K=\mathbf{R}_+^2.
# $$
#
# The order test is $x\preceq_K y$ if $y-x\in K$. Compute
# $$
# y-x=\begin{bmatrix}3-1\\5-2\end{bmatrix}=\begin{bmatrix}2\\3\end{bmatrix}.
# $$
#
# Both components are nonnegative, so $x\preceq_K y$.

# %%
import sympy as sp

point_x = sp.Matrix([1, 2])
point_y = sp.Matrix([3, 5])
difference = point_y - point_x
nonnegative = [entry >= 0 for entry in difference]

print("difference =", difference)
print("nonnegative =", nonnegative)
# Out:
# difference = Matrix([[2], [3]])
# nonnegative = [True, True]

# %% [markdown]
# **Equivalent `casadi` implementation:**

# %%
import casadi as ca

point_x = ca.DM([1, 2])
point_y = ca.DM([3, 5])
difference = point_y - point_x
nonnegative = [bool(difference[index] >= 0) for index in range(difference.numel())]

print("difference =", difference)
print("nonnegative =", nonnegative)
# Out:
# difference = [2, 3]
# nonnegative = [True, True]

# %% [markdown]
# **References:**
#
# [📘 Boyd, S., & Vandenberghe, L. (2004). *Convex Optimization*. Cambridge University Press.](https://web.stanford.edu/~boyd/cvxbook/)
#
# ---
#
# [⬅️ Previous: Perspective and Linear-Fractional Maps](./08_perspective_and_linear_fractional_maps.ipynb) | [Next: Separating and Supporting Hyperplanes ➡️](./10_separating_and_supporting_hyperplanes.ipynb)
#
# ---
