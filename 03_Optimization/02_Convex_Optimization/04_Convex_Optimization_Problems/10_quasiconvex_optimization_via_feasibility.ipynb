# %% [markdown]
# ### 3.2.4.10. Quasiconvex Optimization via Feasibility

# %% [markdown]
# $$f_0(x)\leq t$$

# %% [markdown]
# **Explanation:**
#
# Quasiconvex optimization is usually handled through a sequence of convex feasibility tests. For a proposed objective level, the sublevel constraint is convex; bisection then searches for the smallest feasible level.
#
# The inequality fixes a candidate objective level $t$. Solving the associated feasibility problem asks whether there exists an $x$ whose objective value is no larger than that level.
#
# **Properties:**
# - [Convex functions](../03_Convex_Functions/01_convex_function_definition_and_examples.ipynb) have convex [epigraphs](../03_Convex_Functions/05_sublevel_sets_and_epigraphs.ipynb).
# - Quasiconvex functions have convex sublevel sets.
# - Epigraph transformations replace objectives by constraints.
#
# **Intuition:**
#
# The example checks the same point against two different levels.

# %% [markdown]
# **Numerical Example:**
#
# Let $f(x)=x^2$ and $x=2$. First compute
# $$
# f(2)=2^2=4.
# $$
#
# At level $5$,
# $$
# 4\leq5,
# $$
# so $x=2$ is in the sublevel set. At level $3$,
# $$
# 4\leq3
# $$
# is false, so $x=2$ is not in that lower sublevel set.

# %%
import sympy as sp

function_value = sp.Integer(2) ** 2

print("function_value <= 5 =", function_value <= 5)
print("function_value <= 3 =", function_value <= 3)
# Out:
# function_value <= 5 = True
# function_value <= 3 = False

# %% [markdown]
# **References:**
#
# [📘 Boyd, S., & Vandenberghe, L. (2004). *Convex Optimization*. Cambridge University Press.](https://web.stanford.edu/~boyd/cvxbook/)
#
# ---
#
# [⬅️ Previous: Conic Form Optimization](./09_conic_form_optimization.ipynb) | [Next: Linear-Fractional Programming ➡️](./11_linear_fractional_programming.ipynb)
#
# ---
