# %% [markdown]
# ### 1.1.3.3. Matrix Scalar Multiplication

# %% [markdown]
# $$
# \alpha \mathbf{A} = \alpha
# \begin{bmatrix}
# a_{11} & a_{12} \\
# a_{21} & a_{22}
# \end{bmatrix}
# =
# \begin{bmatrix}
# \alpha a_{11} & \alpha a_{12} \\
# \alpha a_{21} & \alpha a_{22}
# \end{bmatrix}
# $$

# %% [markdown]
# **Explanation:**
#
# Scaling a matrix by a scalar is useful in ML for adjusting learning rates or normalization.
#
# Like the analogous operation for [vectors](../02_Vector/03_vector_scalar_multiplication.ipynb), scaling a [matrix](./01_matrix_definition.ipynb) combines with [matrix addition](./02_matrix_addition.ipynb) to form linear combinations, and those same coefficients reappear in [matrix-vector multiplication](./04_matrix_vector_multiplication.ipynb).
#
# **Example:**
#
# If $\alpha = 2$ and
#
# $$
# \mathbf{A} =
# \begin{bmatrix}
# 1 & 2 \\
# 3 & 4
# \end{bmatrix},
# $$
#
# then
#
# $$
# \alpha \mathbf{A} =
# \begin{bmatrix}
# 2 & 4 \\
# 6 & 8
# \end{bmatrix}.
# $$

# %%
import sympy as sp

scalar = 2
matrix_a = sp.Matrix([[1, 2], [3, 4]])

result = scalar * matrix_a

print("αA =")
sp.pprint(result)
# Out:
# αA =
# ⎡2  4⎤
# ⎢    ⎥
# ⎣6  8⎦

# %% [markdown]
# **References:**
#
# [📘 Aazi, M. (2024). *Mathematics For Machine Learning*](https://www.scribd.com/document/812294393/Mathematics-for-Machine-Learning)
#
# ---
#
# [⬅️ Previous: Matrix Addition](./02_matrix_addition.ipynb) | [Next: Matrix Vector Multiplication ➡️](./04_matrix_vector_multiplication.ipynb)
