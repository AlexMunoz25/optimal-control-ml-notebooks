# %% [markdown]
# ### 1.1.2.7. Orthogonality Condition

# %% [markdown]
# $$
# \mathbf{u} \cdot \mathbf{v} = 0
# $$

# %% [markdown]
# **Explanation:**
#
# Two vectors are orthogonal if their dot product is zero.
# This condition is critical in linear algebra and ML for understanding independence and basis construction.
#
# Because orthogonality is defined by the [dot product](./04_vector_dot_product.ipynb), the same row-column viewpoint later reappears in [matrix multiplication](../03_Matrix/05_matrix_multiplication.ipynb).
#
# **Example:**
#
# If
#
# $$
# \mathbf{u} =
# \begin{bmatrix}
# 1 \\
# 2
# \end{bmatrix},
# \quad
# \mathbf{v} =
# \begin{bmatrix}
# -2 \\
# 1
# \end{bmatrix},
# $$
#
# then
#
# $$
# \mathbf{u} \cdot \mathbf{v} = 1 \cdot (-2) + 2 \cdot 1 = 0,
# $$
#
# confirming orthogonality.

# %%
import sympy as sp

vector_u = sp.Matrix([1, 2])
vector_v = sp.Matrix([-2, 1])

dot_product = vector_u.dot(vector_v)
is_orthogonal = dot_product == 0

print("u · v =", dot_product)
print("Orthogonal:", is_orthogonal)
# Out:
# u · v = 0
# Orthogonal: True

# %% [markdown]
# **References:**
#
# [📘 Aazi, M. (2024). *Mathematics For Machine Learning*](https://www.scribd.com/document/812294393/Mathematics-for-Machine-Learning)
#
# [📗 Fleisch, D. (2012). *A Student's Guide to Vectors and Tensors.* Cambridge University Press.](https://www.cambridge.org/core/books/students-guide-to-vectors-and-tensors/46EB80DBBF3C1C1B06F1B9E34C6D7753)
#
# ---
#
# [⬅️ Previous: Norm of a Vector](./06_vector_norm.ipynb) | [Next: Triple Scalar Product ➡️](./08_vector_triple_scalar_product.ipynb)
