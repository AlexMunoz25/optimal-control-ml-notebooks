# %% [markdown]
# ### 1.1.5.11. Coordinates with Respect to a Basis

# %% [markdown]
# $$
# \mathbf{v} = c_1 \mathbf{b}_1 + c_2 \mathbf{b}_2 + \cdots + c_n \mathbf{b}_n
# $$
#
# $$
# \left[ \mathbf{v} \right]_B =
# \begin{bmatrix}
# c_1 \\
# c_2 \\
# \vdots \\
# c_n
# \end{bmatrix}
# $$

# %% [markdown]
# **Explanation:**
#
# Coordinates are the coefficients of a vector relative to a chosen [basis](./10_basis.ipynb). Orthonormal, orthogonal, and generic bases all describe the same vector space, but they compute those coefficients in different ways. The same coefficient viewpoint later reappears in [contravariant components](../08_Coordinate_Transformations/07_contravariant_components.ipynb).
#
# **Properties:**
# - In an orthonormal basis, each coordinate is a dot product with a basis vector.
# - In a generic basis, the coordinates are obtained by solving a linear system.
#
# **Example:**
#
# Use
#
# $$
# B=\begin{bmatrix}1&1\\1&-1\end{bmatrix},
# \qquad
# \mathbf{v}=\begin{bmatrix}5\\3\end{bmatrix}.
# $$
#
# Solve $B\mathbf{c}=\mathbf{v}$:
#
# $$
# \begin{aligned}
# c_1+c_2&=5,\\
# c_1-c_2&=3.
# \end{aligned}
# $$
#
# Adding the equations gives $2c_1=8$, so $c_1=4$. Then $4+c_2=5$, so $c_2=1$.
#
# Thus
#
# $$
# [\mathbf{v}]_B=\begin{bmatrix}4\\1\end{bmatrix},
# \qquad
# B[\mathbf{v}]_B=\begin{bmatrix}1&1\\1&-1\end{bmatrix}\begin{bmatrix}4\\1\end{bmatrix}=\begin{bmatrix}5\\3\end{bmatrix}.
# $$

# %%
import sympy as sp

basis_matrix = sp.Matrix([[1, 1], [1, -1]])
vector_v = sp.Matrix([5, 3])
coordinate_vector = basis_matrix.LUsolve(vector_v)

print("coordinate_vector =", coordinate_vector)
print("reconstructed_vector =", basis_matrix * coordinate_vector)
# Out:
# coordinate_vector = Matrix([[4], [1]])
# reconstructed_vector = Matrix([[5], [3]])

# %% [markdown]
# **References:**
#
# [📘 Savov, I. (2016). *No Bullshit Guide to Linear Algebra*, Section 5.3 "Coordinates with respect to a basis".](https://minireference.com/static/excerpts/noBSLA_v2_preview.pdf)
# [📘 Fleisch, D. (2012). *A Student's Guide to Vectors and Tensors*, Chapter 4.](https://www.cambridge.org/9780521171908)
#
# ---
#
# [⬅️ Previous: Basis](./10_basis.ipynb) | [Next: Change of Basis ➡️](./12_change_of_basis.ipynb)
#
# ---
