# %% [markdown]
# ### 1.1.6.2. Image Space

# %% [markdown]
# $$
# \operatorname{Im}(T) =
# \left\{
# \mathbf{w} \in W \mid \mathbf{w} = T(\mathbf{v}) \text{ for some } \mathbf{v} \in V
# \right\}
# $$

# %% [markdown]
# **Explanation:**
#
# The image space is the set of all vectors a linear transformation can output. Savov uses it as the transformation-side counterpart of the [column space](../05_Geometrical_Aspects_of_Linear_Algebra/16_matrix_fundamental_spaces.ipynb), so this notebook stays focused on reachable outputs only. Whether the image equals the whole codomain is handled separately in the notebook on [injective, surjective, and bijective transformations](./04_injective_surjective_bijective.ipynb).
#
# **Example:**
#
# For
#
# $$
# T(x, y) =
# \begin{bmatrix}
# x \\
# y \\
# x + y
# \end{bmatrix},
# $$
#
# the image space is
#
# $$
# \operatorname{Im}(T) =
# \operatorname{span}
# \left\{
# \begin{bmatrix}
# 1 \\
# 0 \\
# 1
# \end{bmatrix},
# \begin{bmatrix}
# 0 \\
# 1 \\
# 1
# \end{bmatrix}
# \right\}.
# $$

# %%
import sympy as sp

transformation_matrix = sp.Matrix([[1, 0], [0, 1], [1, 1]])
image_basis = transformation_matrix.columnspace()

print("image_basis =", image_basis)

# %% [markdown]
# **References:**
#
# [Savov, I. (2016). *No Bullshit Guide to Linear Algebra*, Section 6.1 "Input and output spaces".](https://minireference.com/static/excerpts/noBSLA_v2_preview.pdf)
#
# ---
#
# [Previous: Linear Transformation](./01_linear_transformation.ipynb) | [Next: Kernel](./03_kernel.ipynb)
#
# ---
