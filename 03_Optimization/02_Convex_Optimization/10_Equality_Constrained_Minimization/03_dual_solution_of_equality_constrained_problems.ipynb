# %% [markdown]
# ### 3.2.10.3. Dual Solution of Equality Constrained Problems

# %% [markdown]
# $$g(\nu)=\inf_x(f_0(x)+\nu^T(Ax-b))$$

# %% [markdown]
# **Explanation:**
#
# The equality-constrained dual minimizes the Lagrangian over primal variables and then maximizes the resulting concave dual function over the equality multiplier. Feasibility is the equality constraint or its linearized version; optimality is stationarity together with that feasibility condition.
#
# The multiplier vector $\nu$ prices the equality residual $Ax-b$. The dual function $g(\nu)$ is obtained by minimizing the equality-constrained Lagrangian over the primal variable $x$.
#
# **Properties:**
# - Equality constraints introduce unrestricted multipliers.
# - KKT systems couple stationarity and feasibility.
# - Eliminating constraints can reduce the number of variables.
#
# **Intuition:**
#
# The numerical example keeps the equality constraint visible in every algebraic step.

# %% [markdown]
# **Numerical Example:**
#
# For
# $$
# \min \frac12(x_1^2+x_2^2)\quad\text{subject to}\quad x_1+x_2=2,
# $$
# the Lagrangian is
# $$
# L=\frac12(x_1^2+x_2^2)+\nu(x_1+x_2-2).
# $$
#
# Stationarity gives
# $$
# x_1=-\nu,\qquad x_2=-\nu.
# $$
#
# Feasibility gives
# $$
# -\nu-\nu=2\quad\Longrightarrow\quad \nu=-1.
# $$
#
# Therefore $x_1=x_2=1$.

# %%
import sympy as sp

variable_1, variable_2, multiplier = sp.symbols('x_1 x_2 nu')
solution = sp.solve([sp.Eq(variable_1 + multiplier, 0), sp.Eq(variable_2 + multiplier, 0), sp.Eq(variable_1 + variable_2, 2)], [variable_1, variable_2, multiplier])

print("solution =", solution)
# Out:
# solution = {nu: -1, x_1: 1, x_2: 1}

# %% [markdown]
# **Equivalent `casadi` implementation:**

# %%
import casadi as ca

opti = ca.Opti()
decision_variable = opti.variable(2)
opti.minimize(0.5 * ca.dot(decision_variable, decision_variable))
opti.subject_to(decision_variable[0] + decision_variable[1] == 2)
opti.solver("ipopt", {"print_time": False}, {"print_level": 0, "sb": "yes"})
solution = opti.solve()

print("minimizer =", ca.DM(solution.value(decision_variable)))
# Out:
# minimizer = [1, 1]

# %% [markdown]
# **References:**
#
# [📘 Boyd, S., & Vandenberghe, L. (2004). *Convex Optimization*. Cambridge University Press.](https://web.stanford.edu/~boyd/cvxbook/)
#
# ---
#
# [⬅️ Previous: Eliminating Equality Constraints](./02_eliminating_equality_constraints.ipynb) | [Next: Equality Constrained Newton Step ➡️](./04_equality_constrained_newton_step.ipynb)
#
# ---
