# %% [markdown]
# ### 1.1.4.6. Matrix Equations

# %% [markdown]
# $$
# A\vec{x} = \vec{b}
# \qquad \Longrightarrow \qquad
# \vec{x} = A^{-1}\vec{b}
# $$

# %% [markdown]
# **Explanation:**
#
# A system of linear equations can be expressed compactly as a matrix equation $A\vec{x} = \vec{b}$, where $A$ is the coefficient matrix, $\vec{x}$ is the vector of unknowns, and $\vec{b}$ is the vector of constants.
# If $A$ is invertible, the solution is obtained by multiplying both sides by $A^{-1}$ from the left: $\vec{x} = A^{-1}\vec{b}$.
# When manipulating matrix equations, the order of multiplication matters because matrix multiplication is not commutative ($AB \neq BA$ in general).
#
# **Properties:**
# - To solve $A\vec{x} = \vec{b}$, multiply from the **left** by $A^{-1}$
# - To solve $AB = C$ for $A$, multiply from the **right** by $B^{-1}$: $A = CB^{-1}$
# - To solve $AB = C$ for $B$, multiply from the **left** by $A^{-1}$: $B = A^{-1}C$
#
# Writing the system as [matrix-vector multiplication](../03_Matrix/04_matrix_vector_multiplication.ipynb) makes the inverse formula natural once an [inverse of a square matrix](../03_Matrix/11_matrix_inverse.ipynb) exists. This viewpoint can be compared with [Cramer's Rule](../03_Matrix/09_matrix_cramers_rule.ipynb) and with the elimination workflow of [Gauss–Jordan elimination](./04_gauss_jordan_elimination.ipynb).
#
# **Example:**
#
# $$
# \begin{bmatrix} 1 & 2 \\ 3 & 9 \end{bmatrix}
# \begin{bmatrix} x_1 \\ x_2 \end{bmatrix}
# =
# \begin{bmatrix} 5 \\ 21 \end{bmatrix}
# \qquad \Longrightarrow \qquad
# \begin{bmatrix} x_1 \\ x_2 \end{bmatrix}
# = A^{-1}\vec{b}
# =
# \begin{bmatrix} 3 & -\frac{2}{3} \\ -1 & \frac{1}{3} \end{bmatrix}
# \begin{bmatrix} 5 \\ 21 \end{bmatrix}
# =
# \begin{bmatrix} 1 \\ 2 \end{bmatrix}.
# $$

# %%
import sympy as sp

coefficient_matrix = sp.Matrix([
    [1, 2],
    [3, 9]
])
constants = sp.Matrix([5, 21])

inverse = coefficient_matrix.inv()
solution = inverse * constants

print("A^-1 =")
sp.pprint(inverse)
print("\nx = A^-1 b =", list(solution))
# Out:
# A⁻¹ =
# [[ 3.     -0.6667]
#  [-1.      0.3333]]
#
# x = A⁻¹b = [1. 2.]

# %% [markdown]
# **References:**
#
# [Savov, I. (2016). *No Bullshit Guide to Linear Algebra*, Section 4.2 "Matrix equations".](https://minireference.com/static/excerpts/noBSLA_v2_preview.pdf)
#
# ---
#
# [Previous: Number of Solutions](./05_number_of_solutions.ipynb) | [Next: Line in R^3](../05_Geometrical_Aspects_of_Linear_Algebra/01_line_in_r3.ipynb)
#
# ---
