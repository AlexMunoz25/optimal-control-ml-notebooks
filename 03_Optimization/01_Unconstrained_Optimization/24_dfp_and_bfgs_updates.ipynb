# %% [markdown]
# ### 3.1.24. DFP and BFGS Updates

# %% [markdown]
# $$
# D^{k+1}
# = D^k
# + \left(1+\frac{q^{k\mathsf T}D^kq^k}{p^{k\mathsf T}q^k}\right)
# \frac{p^kp^{k\mathsf T}}{p^{k\mathsf T}q^k}
# -\frac{D^kq^kp^{k\mathsf T}+p^kq^{k\mathsf T}D^k}{p^{k\mathsf T}q^k}.
# $$

# %% [markdown]
# **Explanation:**
#
# DFP and BFGS are specific quasi-Newton update formulas for the inverse-Hessian approximation. BFGS is especially important in practice because it tends to be robust and preserves positive definiteness when the curvature condition $p^{k\mathsf T}q^k>0$ holds. The update is built from vector outer products, so it incorporates new curvature information while retaining earlier information. Compared with conjugate gradient, it usually needs more storage but is less sensitive to exact line search.
#
# For learners, the formula may look complicated at first, but its purpose is simple. It must satisfy the secant equation, preserve symmetry and positive definiteness, and alter the previous matrix as economically as possible. Bertsekas presents the update family through these structural properties rather than as an arbitrary algebraic expression.
#
# **Example:**
#
# The figure points to the dual viewpoint: one may update an inverse-Hessian approximation or a Hessian approximation, and the formulas are closely related. The code cell performs one BFGS inverse update and inspects the eigenvalues to see that the resulting matrix is positive definite for the chosen curvature pair.
#
# <img src="../../Figures/030101_berts_fig_1_7_4_hessian_update_exercise.jpeg" alt="Bertsekas Figure 1.7.4: Hessian approximation update exercise" style="width: 60%; height: auto;">

# %%
import numpy as np

inverse_hessian = np.eye(2)
position_increment = np.array([1.0, 0.5])
gradient_increment = np.array([2.0, 1.5])
curvature = position_increment @ gradient_increment
bfgs_update = inverse_hessian.copy()
bfgs_update += (1 + gradient_increment @ inverse_hessian @ gradient_increment / curvature) * np.outer(position_increment, position_increment) / curvature
bfgs_update -= (np.outer(inverse_hessian @ gradient_increment, position_increment) + np.outer(position_increment, gradient_increment @ inverse_hessian)) / curvature
eigenvalues = np.linalg.eigvalsh(bfgs_update)

bfgs_update, eigenvalues

# %% [markdown]
# **References:**
#
# [📘 Bertsekas, D. P. (1999). *Nonlinear Programming* (2nd ed.), Chapter 1 "Unconstrained Optimization". Athena Scientific.](https://www.athenasc.com/nonlinbook.html)
#
# ---
#
# [⬅️ Previous: Quasi-Newton Methods](./23_quasi_newton_methods.ipynb) | [Next: Quasi-Newton Scaling and Comparison ➡️](./25_quasi_newton_scaling_and_comparison.ipynb)
#
# ---
