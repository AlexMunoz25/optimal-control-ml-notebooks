# %% [markdown]
# ### 3.3.23. Convexity with Generalized Inequalities

# %% [markdown]
# $$f(\theta x+(1-\theta)y)\preceq_K\theta f(x)+(1-\theta)f(y)$$

# %% [markdown]
# **Explanation:**
#
# [Cone](03_cones_and_conic_combinations.ipynb)-valued convexity replaces the ordinary scalar order with a [generalized inequality](09_generalized_inequalities_and_proper_cones.ipynb). The difference between the weighted function values is required to lie in a cone, which lets convexity apply to vector and matrix-valued mappings.
#
# The symbol $\preceq_K$ means comparison using the cone $K$. The formula says the function value at a convex combination is below the same convex combination of function values in the [generalized inequality](09_generalized_inequalities_and_proper_cones.ipynb) order.
#
# **Properties:**
# - The cone defines the meaning of inequality.
# - For the nonnegative orthant, every component must be nonnegative.
# - This order supports vector optimization and conic duality.
#
# **Intuition:**
#
# The example checks cone membership by inspecting each component of a difference vector.

# %% [markdown]
# **Numerical Example:**
#
# Let
# $$
# x=\begin{bmatrix}1\\2\end{bmatrix},\quad
# y=\begin{bmatrix}3\\5\end{bmatrix},\quad K=\mathbf{R}_+^2.
# $$
#
# The order test is $x\preceq_K y$ if $y-x\in K$. Compute
# $$
# y-x=\begin{bmatrix}3-1\\5-2\end{bmatrix}=\begin{bmatrix}2\\3\end{bmatrix}.
# $$
#
# Both components are nonnegative, so $x\preceq_K y$.

# %%
import sympy as sp

point_x = sp.Matrix([1, 2])
point_y = sp.Matrix([3, 5])
difference = point_y - point_x
nonnegative = [entry >= 0 for entry in difference]

print("difference =", difference)
print("nonnegative =", nonnegative)
# Out:
# difference = Matrix([[2], [3]])
# nonnegative = [True, True]

# %% [markdown]
# **Equivalent `casadi` implementation:**

# %%
import casadi as ca

point_x = ca.DM([1, 2])
point_y = ca.DM([3, 5])
difference = point_y - point_x
nonnegative = [bool(difference[index] >= 0) for index in range(difference.numel())]

print("difference =", difference)
print("nonnegative =", nonnegative)
# Out:
# difference = [2, 3]
# nonnegative = [True, True]

# %% [markdown]
# **References:**
#
# [📘 Boyd, S., & Vandenberghe, L. (2004). *Convex Optimization*. Cambridge University Press.](https://web.stanford.edu/~boyd/cvxbook/)
#
# ---
#
# [⬅️ Previous: Log-Concave and Log-Convex Functions](./22_log_concave_and_log_convex_functions.ipynb) | [Next: Projection on Convex Sets ➡️](./24_projection_on_convex_sets.ipynb)
#
# ---
