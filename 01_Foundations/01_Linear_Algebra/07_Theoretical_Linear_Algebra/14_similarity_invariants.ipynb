# %% [markdown]
# ### 1.1.7.14. Similarity Invariants

# %% [markdown]
# $$
# \det(A) = \prod_i \lambda_i,
# \qquad
# \operatorname{tr}(A) = \sum_i \lambda_i
# $$

# %% [markdown]
# **Explanation:**
#
# Determinant and trace do not change under similarity transformations. Their invariance follows from the change-of-basis viewpoint of [similarity transformations](../06_Linear_Transformations/13_similarity_transformation.ipynb), and the eigenvalue interpretation explains why these quantities are basis independent.
#
# **Example:**
#
# For
#
# $$
# A=\begin{bmatrix}9&-2\\-2&6\end{bmatrix},
# $$
#
# the determinant is
#
# $$
# \det(A)=9\cdot6-(-2)(-2)=54-4=50.
# $$
#
# The trace is
#
# $$
# \operatorname{tr}(A)=9+6=15.
# $$
#
# The eigenvalues are $5$ and $10$, and they match these invariants:
#
# $$
# 5\cdot10=50=\det(A),
# \qquad
# 5+10=15=\operatorname{tr}(A).
# $$

# %%
import sympy as sp

matrix_a = sp.Matrix([[9, -2], [-2, 6]])
eigenvalues = list(matrix_a.eigenvals().keys())

print("determinant_value =", matrix_a.det())
print("trace_value =", matrix_a.trace())
print("product_of_eigenvalues =", sp.prod(eigenvalues))
print("sum_of_eigenvalues =", sum(eigenvalues))
# Out:
# determinant_value = 50
# trace_value = 15
# product_of_eigenvalues = 50
# sum_of_eigenvalues = 15

# %% [markdown]
# **References:**
#
# [📘 Savov, I. (2016). *No Bullshit Guide to Linear Algebra*, Section 7.1 "Invariant properties of matrices".](https://minireference.com/static/excerpts/noBSLA_v2_preview.pdf)
#
# ---
#
# [⬅️ Previous: Change of Basis to Eigenbasis](./13_change_of_basis_to_eigenbasis.ipynb) | [Next: Normal Matrix ➡️](./15_normal_matrix.ipynb)
#
# ---
